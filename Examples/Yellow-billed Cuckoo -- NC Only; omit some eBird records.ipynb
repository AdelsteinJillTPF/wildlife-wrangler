# %% [markdown]
# # Example: Yellow-billed Cuckoo

# %% [markdown]
# ### Set Variables - fill out stuff in this cell.
# Notes:
# default_coordUncertainty -- coordinateUncertaintyInMeters is often not provided.  Here is an option to use a default.  If you don't want anything entered, set this equal to False (boolean, not string).

# %%
configDir = "T:/Data/" # Path to folder where you saved your wildlifeconfig file.
taxon_id = 'bybcux0'
summary_name = 'test1'
gbif_req_id = 'example1'
gbif_filter_id = 'example2'
default_coordUncertainty = 1000       # Note above.

# %% [markdown]
# There is a bug with mpl_toolkits, the following code is a temporary fix until they resolve the bug.
# https://stackoverflow.com/questions/52911232/basemap-library-using-anaconda-jupyter-notebooks-keyerror-proj-lib/54087410#54087410
#
# os.environ['PROJ_LIB'] should be set equal to something like "c:/Users/jramone/AppData/Local/Continuum/miniconda3/envs/wrangler/Library/share"

# %%
import os
os.environ['PROJ_LIB'] = "c:/Users/nmtarr/AppData/Local/Continuum/miniconda3/envs/wrangler/Library/share"

# %% [markdown]
# ### Setup - nothing to fill out in this cell

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()
import sys
sys.path.append(configDir)
import wranglerconfig as config
codeDir = config.codeDir
paramdb = config.paramdb
sys.path.append(codeDir)
import wrangler_functions as functions
outDir = config.workDir
spdb = outDir + taxon_id + gbif_req_id + gbif_filter_id + '.sqlite'
username = config.gbif_username
password = config.gbif_password
email = config.gbif_email
print("Notebook run " + str(t1))
print(spdb)
connjup = sqlite3.connect(paramdb)
cursorjup = connjup.cursor()
# Get some variables
years = connjup.execute("""SELECT years_range 
                           FROM gbif_requests WHERE request_id = '{0}'""".format(gbif_req_id)).fetchone()[0]
common_name = connjup.execute("""SELECT common_name
                                 FROM taxa_concepts WHERE taxon_id = '{0}'""".format(taxon_id)).fetchone()[0]
# Out:
# Notebook run 2020-12-21 15:09:23.631358
# T:/Occurrence_Records/bybcux0example1example2.sqlite

# %% [markdown]
# # Taxon Concept
# Display species information from your wildlife-wrangler.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM taxa_concepts WHERE taxon_id = '{0}';".format(taxon_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('taxa_concepts')").fetchall()]
sp_dict = dict(zip(cols, vals))
sp_df = pd.DataFrame.from_dict(sp_dict, orient='index', columns=['VALUE'])
sp_df.index.name = 'ATTRIBUTE'
print("TAXON CONCEPT RECORD")
print(sp_df)
# Out:
# TAXON CONCEPT RECORD
#                                                    VALUE
# ATTRIBUTE
# taxon_id                                         bybcux0
# fws_id                                              None
# gap_id                                            bybcux
# itis_tsn                                          177831
# gbif_id                                          2496287
# ebird_id                                            None
# common_name                         yellow-billed cuckoo
# scientific_name                      Coccyzus americanus
# start_year                                          None
# split_from                                          None
# end_year                                            None
# lumped_into                                         None
# geometry                                            None
# detection_distance_meters                            100
# retro_misid_risk                                    None
# vetted_how                                          None
# vetted_who                                          None
# vetted_date                                         None
# notes                      Manually entered for use i...

# %% [markdown]
# # Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
request_df = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id), con=connjup)
print("THE REQUEST FILTER SET")
print(request_df.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                           example1
# source                                   GBIF
# lat_range                                None
# lon_range                                None
# years_range                         1999,2020
# months_range                             1,12
# geoissue                                False
# coordinate                               True
# country                                    US
# geometry        POLYGON ((-84.480785172140...
# creator                               N. Tarr
# notes                     This is an example.
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the output occurrence record sqlite database.

# %%
filter_df = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(gbif_filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(filter_df.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                          example2
# dataset                                                GBIF
# institutions_omit                               iNaturalist
# collection_codes_omit         EBIRD_CAN, EBIRD_NJ, EBIRD_AK
# datasets_omit                                          None
# has_coordinate_uncertainty                                0
# max_coordinate_uncertainty                            10000
# bases_omit                    FOSSIL_SPECIMEN, PRESERVED...
# sampling_protocols_omit                                None
# issues_omit                    GEODETIC_DATUM_ASSUMED_WGS84
# duplicates_OK                                         False
# creator                                             N. Tarr
# notes                                   This is an example.
# Name: 0, dtype: object

# %% [markdown]
# ## Filter set justification
#
# **default_coord_uncertainty:**
#
# **years_range:**
#
# **months_range:**
#
# **geoissue:**
#
# **coordinate:**
#
# **country:**
#
# **geometry:**
#
# **collection_codes_omit:**
#
# **institutions_omit:**
#
# **datasets_omit:**
#
# **has_coordinate_uncertainty:**
#
# **max_coordinate_uncertainty:**
#
# **bases_omit:**
#
# **sampling_protocols_omit:**
#
# **issues_omit:**
#
# **duplicates:**

# %%
functions.retrieve_gbif_occurrences(codeDir, taxon_id, paramdb, spdb, gbif_req_id, gbif_filter_id, 
                                    default_coordUncertainty, outDir, summary_name, username,
                                   password, email)
# Out:
# SPATIALITE_SECURITY set to relaxed
# Created occurrence db: 0:00:00.541936
# Got request params and sorted out geometry constraints: 0:00:00.015618
# 29298 records available
# Downloaded records: 0:02:45.915383
# Summarized fields returned: 0:12:09.778397
# Created summary table of request results: 0:00:00.096134
# Performed post-request filtering: 0:00:00.181142
# Calculated new columns, deleted some too: 0:00:00.081741
# 6467 duplicate records dropped: 0:00:27.201806
# Inserted records into table: 0:00:00.727789
# Summarized unique values retained: 0:00:00.015627
# Updated occurrences table geometry column: 0:00:07.107429
# Buffered points: 0:00:18.889649
# Exported shapefile: 0:00:03.860456
#
# Records saved in T:/Occurrence_Records/bybcux0example1example2.sqlite

# %% [markdown]
# ### Connect to output database, record species and filter information.

# %%
conn_occ= sqlite3.connect(spdb)
curs_occ = conn_occ.cursor()
sp_df.to_sql(name='taxon_concept', con=conn_occ, if_exists='replace')
request_df.to_sql(name=gbif_req_id, con=conn_occ, if_exists='replace')
filter_df.to_sql(name=gbif_filter_id, con=conn_occ, if_exists='replace')

# %% [markdown]
# ### How many records made it through the filters?
# This is the number of species occurrence records that were actually saved in the occurrence record sqlite database.

# %%
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE taxon_id = '{0}'".format(taxon_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 22689 records

# %% [markdown]
# # Sources
# #### Pre-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sources = pd.read_sql(sql="SELECT * FROM pre_filter_source_counts;", con=conn_occ)
print(sources)
# Out:
# GBIF
#    institutionCode  collectionCode                    datasetName      0
# 0              CAS             ORN                        UNKNOWN      1
# 1              CLO           EBIRD                        UNKNOWN  28516
# 2              CLO        EBIRD_AK                        UNKNOWN      2
# 3              CLO    EBIRD_ATL_VA                        UNKNOWN    429
# 4              CLO       EBIRD_BCN                        UNKNOWN     11
# 5              CLO  EBIRD_CAMERICA                        UNKNOWN     18
# 6              CLO       EBIRD_CAN                        UNKNOWN     29
# 7              CLO        EBIRD_CB                        UNKNOWN      5
# 8              CLO        EBIRD_MA                        UNKNOWN      2
# 9              CLO        EBIRD_ME                        UNKNOWN     44
# 10             CLO       EBIRD_MEX                        UNKNOWN      4
# 11             CLO        EBIRD_MO                        UNKNOWN      1
# 12             CLO        EBIRD_NJ                        UNKNOWN      2
# 13             CLO        EBIRD_PA                        UNKNOWN      5
# 14             CLO       EBIRD_PNW                        UNKNOWN     12
# 15             CLO        EBIRD_PR                        UNKNOWN      2
# 16             CLO        EBIRD_QC                        UNKNOWN      8
# 17             CLO        EBIRD_TX                        UNKNOWN      4
# 18             CLO        EBIRD_VA                        UNKNOWN     76
# 19             CLO      EBIRD_VINS                        UNKNOWN      1
# 20             CLO        EBIRD_WI                        UNKNOWN     18
# 21             PSM            Bird                        UNKNOWN      1
# 22           SBMNH              AV                        UNKNOWN      1
# 23            UWBM            Bird                        UNKNOWN      3
# 24     iNaturalist    Observations  iNaturalist research-grade...    103

# %% [markdown]
# #### Post-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sql = "SELECT institutionCode, collectionCode, datasetName, COUNT(occ_id) FROM occurrences GROUP BY institutionCode, collectionCode, datasetName;"
sources = pd.read_sql(sql=sql, con=conn_occ)
print(sources)
# Out:
# GBIF
#    institutionCode  collectionCode datasetName  COUNT(occ_id)
# 0              CLO           EBIRD     UNKNOWN          22179
# 1              CLO    EBIRD_ATL_VA     UNKNOWN            330
# 2              CLO       EBIRD_BCN     UNKNOWN              9
# 3              CLO  EBIRD_CAMERICA     UNKNOWN             13
# 4              CLO        EBIRD_CB     UNKNOWN              4
# 5              CLO        EBIRD_MA     UNKNOWN              2
# 6              CLO        EBIRD_ME     UNKNOWN             33
# 7              CLO       EBIRD_MEX     UNKNOWN              4
# 8              CLO        EBIRD_MO     UNKNOWN              1
# 9              CLO        EBIRD_PA     UNKNOWN              5
# 10             CLO       EBIRD_PNW     UNKNOWN              9
# 11             CLO        EBIRD_PR     UNKNOWN              2
# 12             CLO        EBIRD_QC     UNKNOWN              8
# 13             CLO        EBIRD_TX     UNKNOWN              3
# 14             CLO        EBIRD_VA     UNKNOWN             69
# 15             CLO      EBIRD_VINS     UNKNOWN              1
# 16             CLO        EBIRD_WI     UNKNOWN             17

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = pd.read_sql(sql="SELECT value as basisOfRecord, count FROM pre_filter_value_counts WHERE attribute = 'bases';", con=conn_occ)
print(bases)
# Out:
#         basisOfRecord  count
# 0   HUMAN_OBSERVATION  29292
# 1  PRESERVED_SPECIMEN      6

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT basisOfRecord, COUNT(occ_id) as count FROM occurrences GROUP BY basisOfRecord;"
bases = pd.read_sql(sql=sql, con=conn_occ)
print(bases)
# Out:
#        basisOfRecord  count
# 0  HUMAN_OBSERVATION  22689

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocol = pd.read_sql(sql="SELECT value as samplingProtocol, count FROM pre_filter_value_counts WHERE attribute = 'samplingProtocols';", con=conn_occ)
print(protocol)
# Out:
#   samplingProtocol  count
# 0          UNKNOWN  29298

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT samplingProtocol, COUNT(occ_id) as count FROM occurrences GROUP BY samplingProtocol;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#   samplingProtocol  count
# 0          UNKNOWN  22689

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
iss = pd.read_sql(sql="SELECT value as issues, count FROM pre_filter_value_counts WHERE attribute = 'issues';", con=conn_occ)
pd.set_option('display.max_colwidth', 80)
print(iss)
# Out:
#                                                                             issues  count
# 0                                ['AMBIGUOUS_INSTITUTION', 'AMBIGUOUS_COLLECTION']      1
# 1                             ['COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_FUZZY']  29189
# 2                                 ['COORDINATE_ROUNDED', 'COLLECTION_MATCH_FUZZY']      1
# 3  ['COORDINATE_ROUNDED', 'CONTINENT_INVALID', 'INSTITUTION_MATCH_FUZZY', 'INST...      3
# 4  ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84', 'INSTITUTION_MATCH_NO...     81
# 5  ['COORDINATE_ROUNDED', 'INSTITUTION_MATCH_FUZZY', 'INSTITUTION_COLLECTION_MI...      1
# 6  ['GEODETIC_DATUM_ASSUMED_WGS84', 'INSTITUTION_MATCH_NONE', 'COLLECTION_MATCH...     22

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT issues, COUNT(occ_id) as count FROM occurrences GROUP BY issues;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#                                           issues  count
# 0  COLLECTION_MATCH_NONE;INSTITUTION_MATCH_FUZZY  22689

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
shp1 = {'file': '{0}{1}_polygons'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'magenta',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
map_these=[shp1]
    
title="{1} ({0})".format(years, common_name)
try:
    functions.MapShapefilePolygons(map_these=map_these, title=title)
except Exception as e:
    print("Unable to map:  " + str(e))

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of records")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of records")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("meters")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
plt.figure(figsize=(16,4))
plt.boxplot(occ_cert, vert=False)
plt.xlabel("meters")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("meters")
plt.title("Coordinate Uncertainties Below 2km")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainties Below 2km')

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM unique_values WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)
# Out:
# UNKNOWN

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM unique_values WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)
# Out:
# UNKNOWN

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# More than 20 remarks, consult the occurrence database.

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ)#, index_col='index')
fields_summary.index.name = 'Field'
pd.set_option('display.max_rows', 250)
print(fields_summary)
# Out:
#                                                attribute  included(n)  populated(n)
# Field
# 0                                 acceptedScientificName        29298         29298
# 1                                       acceptedTaxonKey        29298         29298
# 2                                           accessRights            1             1
# 3                                          basisOfRecord        29298         29298
# 4                                          catalogNumber        29298         29298
# 5                                                  class        29298         29298
# 6                                               classKey        29298         29298
# 7                                         collectionCode        29298         29298
# 8                                          collectionKey            1             1
# 9                                              continent            3             3
# 10                         coordinateUncertaintyInMeters           92            92
# 11                                               country        29298         29298
# 12                                           countryCode        29298         29298
# 13                                                county        29195         29195
# 14                                               crawlId        29298         29298
# 15                                            datasetKey        29298         29298
# 16                                           datasetName          103           103
# 17                                        dateIdentified          101           101
# 18                                                   day        29297         29297
# 19                                       decimalLatitude        29298         29298
# 20                                      decimalLongitude        29298         29298
# 21                                                 depth            3             3
# 22                                         depthAccuracy            3             3
# 23                                     dynamicProperties            1             1
# 24                                             elevation            3             3
# 25                                     elevationAccuracy            3             3
# 26                                          endDayOfYear            1             1
# 27                                    establishmentMeans            2             2
# 28                                             eventDate        29298         29298
# 29                                             eventTime           98            98
# 30                                            extensions        29298            86
# 31                                                 facts        29298             0
# 32                                                family        29298         29298
# 33                                             familyKey        29298         29298
# 34                                            fieldNotes            3             3
# 35                                           fieldNumber            3             3
# 36                                                  gadm        29298         29136
# 37                                                gbifID        29298         29298
# 38                                           genericName        29298         29298
# 39                                                 genus        29298         29298
# 40                                              genusKey        29298         29298
# 41                                         geodeticDatum        29298         29298
# 42                                  georeferenceProtocol            5             5
# 43                                   georeferenceSources            1             1
# 44                        georeferenceVerificationStatus            5             5
# 45                                       georeferencedBy            1             1
# 46                                     georeferencedDate            1             1
# 47                                  higherClassification            6             6
# 48                                       higherGeography            6             6
# 49                                hostingOrganizationKey        29298         29298
# 50         http://rs.tdwg.org/dwc/terms/organismQuantity            3             3
# 51     http://rs.tdwg.org/dwc/terms/organismQuantityType            3             3
# 52                               http://unknown.org/nick          103           103
# 53                  http://unknown.org/occurrenceDetails          103           103
# 54                                      identificationID          101           101
# 55                                          identifiedBy          102           102
# 56                                       identifiedByIDs        29298             4
# 57                                            identifier        29298         29298
# 58                                           identifiers        29298             0
# 59                                       individualCount        28313         28313
# 60                                   informationWithheld            7             7
# 61                                  infraspecificEpithet            1             1
# 62                                       installationKey        29298         29298
# 63                                       institutionCode        29298         29298
# 64                                         institutionID            2             2
# 65                                        institutionKey        29194         29194
# 66                                           isInCluster        29298         29298
# 67                                                issues        29298         29298
# 68                                                   key        29298         29298
# 69                                               kingdom        29298         29298
# 70                                            kingdomKey        29298         29298
# 71                                              language            3             3
# 72                                           lastCrawled        29298         29298
# 73                                       lastInterpreted        29298         29298
# 74                                            lastParsed        29298         29298
# 75                                               license        29298         29298
# 76                                              locality        29195         29195
# 77                                                 media        29298            86
# 78                                              modified          106           106
# 79                                                 month        29298         29298
# 80                                     nomenclaturalCode            5             5
# 81                                          occurrenceID        29298         29298
# 82                                     occurrenceRemarks           27            27
# 83                                      occurrenceStatus        29298         29298
# 84                                                 order        29298         29298
# 85                                              orderKey        29298         29298
# 86                                      organismQuantity            3             3
# 87                                  organismQuantityType            3             3
# 88                                                phylum        29298         29298
# 89                                             phylumKey        29298         29298
# 90                                          preparations            5             5
# 91                                              protocol        29298         29298
# 92                                     publishingCountry        29298         29298
# 93                                      publishingOrgKey        29298         29298
# 94                                            recordedBy        29297         29297
# 95                                         recordedByIDs        29298             3
# 96                                            references          104           104
# 97                                             relations        29298             0
# 98                                                rights          103           103
# 99                                          rightsHolder          103           103
# 100                                       scientificName        29298         29298
# 101                                                  sex            5             5
# 102                                              species        29298         29298
# 103                                           speciesKey        29298         29298
# 104                                      specificEpithet        29298         29298
# 105                                       startDayOfYear            1             1
# 106                                        stateProvince        29298         29298
# 107                                              taxonID          103           103
# 108                                             taxonKey        29298         29298
# 109                                            taxonRank        29298         29298
# 110                                      taxonomicStatus        29298         29298
# 111                                                 type            6             6
# 112                             verbatimCoordinateSystem            4             4
# 113                                    verbatimEventDate          107           107
# 114                                     verbatimLocality          104           104
# 115                                       vernacularName        29189         29189
# 116                                                 year        29298         29298

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:17:41.480220
