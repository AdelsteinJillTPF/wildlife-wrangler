# %% [markdown]
# # Marbled Salamander

# %% [markdown]
# ### Set Variables - fill out stuff in this cell.
# Notes:
# default_coordUncertainty -- coordinateUncertaintyInMeters is often not provided.  Here is an option to use a default.  If you don't want anything entered, set this equal to False (boolean, not string).

# %%
configDir = "T:/Dat/Data"  # Path to folder where you saved your wildlifeconfig file.
taxon_id = 'amasax0'
summary_name = 'test1'
gbif_req_id = 'Gr24'
gbif_filter_id = 'test1'
default_coordUncertainty = 1000       # Note above.

# %% [markdown]
# There is a bug with mpl_toolkits, the following code is a temporary fix until they resolve the bug.
# https://stackoverflow.com/questions/52911232/basemap-library-using-anaconda-jupyter-notebooks-keyerror-proj-lib/54087410#54087410
#
# os.environ['PROJ_LIB'] should be set equal to something like "c:/Users/jramone/AppData/Local/Continuum/miniconda3/envs/wrangler/Library/share"

# %%
import os
os.environ['PROJ_LIB'] = "c:/Users/nm/AppData/Local/Continuum/miniconda3/envs/wrangler/Library/share"

# %% [markdown]
# ### Setup - nothing to fill out in this cell

# %%
# %matplotlib inline
import sqlite3
import pprint
import json
import pandas as pd
import numpy as np
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 30)
pd.set_option('display.max_rows', 150)
from IPython.display import Image
from pygbif import occurrences
import matplotlib.pyplot as plt
import os
from datetime import datetime
t1 = datetime.now()
import sys
sys.path.append(configDir)
import wranglerconfig as config
codeDir = config.codeDir
paramdb = config.paramdb
sys.path.append(codeDir)
import wrangler_functions as functions
outDir = config.workDir
spdb = outDir + taxon_id + gbif_req_id + gbif_filter_id + '.sqlite'
username = config.gbif_username
password = config.gbif_password
email = config.gbif_email
print("Notebook run " + str(t1))
print(spdb)
connjup = sqlite3.connect(paramdb)
cursorjup = connjup.cursor()
# Get some variables
years = connjup.execute("""SELECT years_range 
                           FROM gbif_requests WHERE request_id = '{0}'""".format(gbif_req_id)).fetchone()[0]
common_name = connjup.execute("""SELECT common_name
                                 FROM taxa_concepts WHERE taxon_id = '{0}'""".format(taxon_id)).fetchone()[0]
# Out:
# Notebook run 2020-12-21 15:03:23.788760
# T:/Occurrence_Records/amasax0Gr24test1.sqlite

# %% [markdown]
# # Taxon Concept
# Display species information from your wildlife-wrangler.sqlite database.

# %%
vals = cursorjup.execute("SELECT * FROM taxa_concepts WHERE taxon_id = '{0}';".format(taxon_id)).fetchall()[0]
cols = [x[1] for x in cursorjup.execute("PRAGMA table_info('taxa_concepts')").fetchall()]
sp_dict = dict(zip(cols, vals))
sp_df = pd.DataFrame.from_dict(sp_dict, orient='index', columns=['VALUE'])
sp_df.index.name = 'ATTRIBUTE'
print("TAXON CONCEPT RECORD")
print(sp_df)
# Out:
# TAXON CONCEPT RECORD
#                                                    VALUE
# ATTRIBUTE
# taxon_id                                         amasax0
# fws_id                                              None
# gap_id                                            aMASAx
# itis_tsn                                          173591
# gbif_id                                          2432006
# ebird_id                                            None
# common_name                           Marbled Salamander
# scientific_name                         Ambystoma opacum
# start_year                                          1807
# split_from                                          None
# end_year                                            None
# lumped_into                                         None
# geometry                                            None
# detection_distance_meters                              0
# retro_misid_risk                                    None
# vetted_how                                  NS,GBIF,IUCN
# vetted_who                                     M. Rubino
# vetted_date                                   04/23/2020
# notes                      See Kraus (1988), Shaffer ...

# %% [markdown]
# # Filters
# Display the parameters of the request filter set.  These are deployed during the step where records are retrieved from the API.

# %%
request_df = pd.read_sql_query(sql="SELECT * FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id), con=connjup)
print("THE REQUEST FILTER SET")
print(request_df.loc[0])
# Out:
# THE REQUEST FILTER SET
# request_id                               Gr24
# source                                   GBIF
# lat_range                                None
# lon_range                                None
# years_range                         1999,2020
# months_range                             1,12
# geoissue                                False
# coordinate                               True
# country                                    US
# geometry                                 None
# creator                               N. Tarr
# notes           Used for tests of large do...
# Name: 0, dtype: object

# %% [markdown]
# Display the parameters of the post-request filter set.  These are deployed after the records are retrieved from the API, but before they are stored in the output occurrence record sqlite database.

# %%
filter_df = pd.read_sql_query(sql="SELECT * FROM gbif_filters WHERE filter_id = '{0}'".format(gbif_filter_id), con=connjup)
print("THE POST REQUEST FILTER SET")
print(filter_df.loc[0])
# Out:
# THE POST REQUEST FILTER SET
# filter_id                                   test1
# dataset                                      GBIF
# institutions_omit                             MCZ
# collection_codes_omit                        None
# datasets_omit                                None
# has_coordinate_uncertainty                      0
# max_coordinate_uncertainty                  10000
# bases_omit                    MACHINE_OBSERVATION
# sampling_protocols_omit                      None
# issues_omit                                  None
# duplicates_OK                               False
# creator                                      None
# notes                                        None
# Name: 0, dtype: object

# %% [markdown]
# ## Filter set justification
#
# **default_coord_uncertainty:**
#
# **years_range:**
#
# **months_range:**
#
# **geoissue:**
#
# **coordinate:**
#
# **country:**
#
# **geometry:**
#
# **collection_codes_omit:**
#
# **institutions_omit:**
#
# **datasets_omit:**
#
# **has_coordinate_uncertainty:**
#
# **max_coordinate_uncertainty:**
#
# **bases_omit:**
#
# **sampling_protocols_omit:**
#
# **issues_omit:**
#
# **duplicates:**

# %%
functions.retrieve_gbif_occurrences(codeDir, taxon_id, paramdb, spdb, gbif_req_id, gbif_filter_id, 
                                    default_coordUncertainty, outDir, summary_name, username,
                                   password, email)
# Out:
# SPATIALITE_SECURITY set to relaxed
# Created occurrence db: 0:00:00.298031
# Got request params and sorted out geometry constraints: 0:00:00
# 1856 records available
# Downloaded records: 0:00:13.228557
# Summarized fields returned: 0:00:54.686010
# Created summary table of request results: 0:00:00.037098
# Performed post-request filtering: 0:00:00.020098
# Calculated new columns, deleted some too: 0:00:00.014000
# 79 duplicate records dropped: 0:00:00.627186
# Inserted records into table: 0:00:00.058909
# Summarized unique values retained: 0:00:00.015639
# Updated occurrences table geometry column: 0:00:00.387311
# Buffered points: 0:00:01.477609
# Exported shapefile: 0:00:00.400551
#
# Records saved in T:/Occurrence_Records/amasax0Gr24test1.sqlite

# %% [markdown]
# ### Connect to output database, record species and filter information.

# %%
conn_occ= sqlite3.connect(spdb)
curs_occ = conn_occ.cursor()
sp_df.to_sql(name='taxon_concept', con=conn_occ, if_exists='replace')
request_df.to_sql(name=gbif_req_id, con=conn_occ, if_exists='replace')
filter_df.to_sql(name=gbif_filter_id, con=conn_occ, if_exists='replace')

# %% [markdown]
# ### How many records made it through the filters?
# This is the number of species occurrence records that were actually saved in the occurrence record sqlite database.

# %%
record_count = curs_occ.execute("SELECT COUNT(occ_id) FROM occurrences WHERE taxon_id = '{0}'".format(taxon_id)).fetchone()
print(str(record_count[0]) + " records")
# Out:
# 1298 records

# %% [markdown]
# # Sources
# #### Pre-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sources = pd.read_sql(sql="SELECT * FROM pre_filter_source_counts;", con=conn_occ)
print(sources)
# Out:
# GBIF
#    institutionCode                 collectionCode                    datasetName     0
# 0              AUM                          Herps                        UNKNOWN    12
# 1             CUMV                          Herps                        UNKNOWN     1
# 2             FHSM                           HERP                        UNKNOWN     8
# 3              GSU                       GSU-Herp  Georgia Southern Universit...     4
# 4              MCZ                           Herp                        UNKNOWN    18
# 5             NCSM                           Herp    NCSM Herpetology Collection    71
# 6             NEON                      HEVC-GBTS                        UNKNOWN     6
# 7             OMNH                           OCGR  Oklahoma Collection of Gen...     2
# 8              SLU                          Herps                        UNKNOWN     8
# 9             TCWC                    Herpetology                        UNKNOWN    24
# 10            TNHC         Ichthyology Collection                        UNKNOWN     6
# 11              UF                           Herp                        UNKNOWN    16
# 12         UNKNOWN                        UNKNOWN                        UNKNOWN     2
# 13            USNM          Amphibians & Reptiles            NMNH Extant Biology     8
# 14            UTEP  Amphibian and reptile spec...                        UNKNOWN     3
# 15             YPM                             VZ                        UNKNOWN    80
# 16     iNaturalist                   Observations  iNaturalist research-grade...  1587

# %% [markdown]
# #### Post-filters

# %%
tables = cursorjup.execute("SELECT table_name FROM table_descriptions").fetchall()
tables = [x[0] for x in tables]

filter_sets = [gbif_req_id, gbif_filter_id]

sources = []
for s in filter_sets:
    s = s.strip()
    for tab in tables:
        columns = cursorjup.execute("SELECT column_name FROM column_descriptions WHERE table_name = '{0}'".format(tab)).fetchall()
        columns = [x[0] for x in columns]
        for col in columns:
            try:
                a = cursorjup.execute("SELECT source FROM {1} WHERE {2} = '{0}'".format(s, tab, col)).fetchone()[0]
                sources.append(a)
            except:
                pass
print(list(set(sources))[0])

sql = "SELECT institutionCode, collectionCode, datasetName, COUNT(occ_id) FROM occurrences GROUP BY institutionCode, collectionCode, datasetName;"
sources = pd.read_sql(sql=sql, con=conn_occ)
print(sources)
# Out:
# GBIF
#    institutionCode                 collectionCode                    datasetName  COUNT(occ_id)
# 0              AUM                          Herps                        UNKNOWN             11
# 1             CUMV                          Herps                        UNKNOWN              1
# 2             FHSM                           HERP                        UNKNOWN              6
# 3              GSU                       GSU-Herp  Georgia Southern Universit...              4
# 4             NCSM                           Herp    NCSM Herpetology Collection             53
# 5             NEON                      HEVC-GBTS                        UNKNOWN              6
# 6             OMNH                           OCGR  Oklahoma Collection of Gen...              2
# 7              SLU                          Herps                        UNKNOWN              5
# 8             TCWC                    Herpetology                        UNKNOWN             11
# 9             TNHC         Ichthyology Collection                        UNKNOWN              4
# 10              UF                           Herp                        UNKNOWN              3
# 11         UNKNOWN                        UNKNOWN                        UNKNOWN              1
# 12            USNM          Amphibians & Reptiles            NMNH Extant Biology              5
# 13            UTEP  Amphibian and reptile spec...                        UNKNOWN              2
# 14             YPM                             VZ                        UNKNOWN             67
# 15     iNaturalist                   Observations  iNaturalist research-grade...           1117

# %% [markdown]
# # Bases
# #### Pre-filter

# %%
bases = pd.read_sql(sql="SELECT value as basisOfRecord, count FROM pre_filter_value_counts WHERE attribute = 'bases';", con=conn_occ)
print(bases)
# Out:
#          basisOfRecord  count
# 0    HUMAN_OBSERVATION   1587
# 1  MACHINE_OBSERVATION     10
# 2   PRESERVED_SPECIMEN    259

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT basisOfRecord, COUNT(occ_id) as count FROM occurrences GROUP BY basisOfRecord;"
bases = pd.read_sql(sql=sql, con=conn_occ)
print(bases)
# Out:
#         basisOfRecord  count
# 0   HUMAN_OBSERVATION   1117
# 1  PRESERVED_SPECIMEN    181

# %% [markdown]
# # Protocols
# #### Pre-filters

# %%
protocol = pd.read_sql(sql="SELECT value as samplingProtocol, count FROM pre_filter_value_counts WHERE attribute = 'samplingProtocols';", con=conn_occ)
print(protocol)
# Out:
#   samplingProtocol  count
# 0          UNKNOWN   1854
# 1      wild caught      2

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT samplingProtocol, COUNT(occ_id) as count FROM occurrences GROUP BY samplingProtocol;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#   samplingProtocol  count
# 0          UNKNOWN   1297
# 1      wild caught      1

# %% [markdown]
# # Issues
# #### Pre-filters

# %%
iss = pd.read_sql(sql="SELECT value as issues, count FROM pre_filter_value_counts WHERE attribute = 'issues';", con=conn_occ)
pd.set_option('display.max_colwidth', 80)
print(iss)
# Out:
#                                                                              issues  count
# 0                                                        ['COLLECTION_MATCH_FUZZY']      8
# 1                              ['COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_FUZZY']      1
# 2        ['COORDINATE_ROUNDED', 'COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_FUZZY']      1
# 3   ['COORDINATE_ROUNDED', 'COORDINATE_REPROJECTED', 'OCCURRENCE_STATUS_INFERRED...      1
# 4   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84', 'COORDINATE_UNCERTAIN...      1
# 5   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84', 'INSTITUTION_MATCH_NO...   1378
# 6   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_ASSUMED_WGS84', 'OCCURRENCE_STATUS_IN...      1
# 7   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_INVALID', 'GEODETIC_DATUM_ASSUMED_WGS...     12
# 8   ['COORDINATE_ROUNDED', 'GEODETIC_DATUM_INVALID', 'GEODETIC_DATUM_ASSUMED_WGS...      6
# 9                         ['COORDINATE_ROUNDED', 'INSTITUTION_COLLECTION_MISMATCH']      1
# 10      ['COORDINATE_ROUNDED', 'INSTITUTION_MATCH_FUZZY', 'COLLECTION_MATCH_FUZZY']     19
# 11  ['COORDINATE_ROUNDED', 'OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT', '...      5
# 12  ['COORDINATE_ROUNDED', 'OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT', '...     70
# 13  ['COORDINATE_ROUNDED', 'PRESUMED_NEGATED_LONGITUDE', 'INSTITUTION_MATCH_FUZZ...      5
# 14          ['COUNTRY_DERIVED_FROM_COORDINATES', 'INSTITUTION_COLLECTION_MISMATCH']      1
# 15             ['GEODETIC_DATUM_ASSUMED_WGS84', 'COUNTRY_DERIVED_FROM_COORDINATES']      2
# 16  ['GEODETIC_DATUM_ASSUMED_WGS84', 'INSTITUTION_MATCH_FUZZY', 'COLLECTION_MATC...      2
# 17  ['GEODETIC_DATUM_ASSUMED_WGS84', 'INSTITUTION_MATCH_FUZZY', 'INSTITUTION_COL...      6
# 18  ['GEODETIC_DATUM_ASSUMED_WGS84', 'INSTITUTION_MATCH_NONE', 'COLLECTION_MATCH...    208
# 19  ['GEODETIC_DATUM_ASSUMED_WGS84', 'OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL...      8
# 20  ['GEODETIC_DATUM_ASSUMED_WGS84', 'OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL...      8
# 21                                              ['INSTITUTION_COLLECTION_MISMATCH']     12
# 22                            ['INSTITUTION_MATCH_FUZZY', 'COLLECTION_MATCH_FUZZY']     16
# 23  ['OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT', 'AMBIGUOUS_INSTITUTION'...      2
# 24  ['OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT', 'COLLECTION_MATCH_NONE'...     72
# 25  ['PRESUMED_NEGATED_LONGITUDE', 'COLLECTION_MATCH_NONE', 'INSTITUTION_MATCH_F...      3
# 26                ['PRESUMED_NEGATED_LONGITUDE', 'INSTITUTION_COLLECTION_MISMATCH']      3
# 27                     ['RECORDED_DATE_INVALID', 'INSTITUTION_COLLECTION_MISMATCH']      4

# %% [markdown]
# #### Post-filters

# %%
sql = "SELECT issues, COUNT(occ_id) as count FROM occurrences GROUP BY issues;"
print(pd.read_sql(sql=sql, con=conn_occ))
# Out:
#                                                                              issues  count
# 0                                                            COLLECTION_MATCH_FUZZY      5
# 1                                     COLLECTION_MATCH_NONE;INSTITUTION_MATCH_FUZZY      1
# 2                  COORDINATE_ROUNDED;COLLECTION_MATCH_NONE;INSTITUTION_MATCH_FUZZY      1
# 3   COORDINATE_ROUNDED;COORDINATE_REPROJECTED;OCCURRENCE_STATUS_INFERRED_FROM_IN...      1
# 4   COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_UNCERTAINTY_METER...      1
# 5   COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;INSTITUTION_MATCH_NONE;COLLE...    933
# 6   COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;OCCURRENCE_STATUS_INFERRED_F...      1
# 7                                COORDINATE_ROUNDED;INSTITUTION_COLLECTION_MISMATCH      1
# 8                 COORDINATE_ROUNDED;INSTITUTION_MATCH_FUZZY;COLLECTION_MATCH_FUZZY      9
# 9   COORDINATE_ROUNDED;OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT;COLLECTI...      3
# 10  COORDINATE_ROUNDED;OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT;INSTITUT...     52
# 11  COORDINATE_ROUNDED;PRESUMED_NEGATED_LONGITUDE;INSTITUTION_MATCH_FUZZY;COLLEC...      2
# 12                 COUNTRY_DERIVED_FROM_COORDINATES;INSTITUTION_COLLECTION_MISMATCH      1
# 13                    GEODETIC_DATUM_ASSUMED_WGS84;COUNTRY_DERIVED_FROM_COORDINATES      1
# 14      GEODETIC_DATUM_ASSUMED_WGS84;INSTITUTION_MATCH_FUZZY;COLLECTION_MATCH_FUZZY      2
# 15  GEODETIC_DATUM_ASSUMED_WGS84;INSTITUTION_MATCH_FUZZY;INSTITUTION_COLLECTION_...      4
# 16        GEODETIC_DATUM_ASSUMED_WGS84;INSTITUTION_MATCH_NONE;COLLECTION_MATCH_NONE    183
# 17  GEODETIC_DATUM_ASSUMED_WGS84;OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUN...      5
# 18  GEODETIC_DATUM_ASSUMED_WGS84;OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUN...      6
# 19                                                  INSTITUTION_COLLECTION_MISMATCH     10
# 20                                   INSTITUTION_MATCH_FUZZY;COLLECTION_MATCH_FUZZY      3
# 21  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT;AMBIGUOUS_INSTITUTION;COLLE...      1
# 22  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT;COLLECTION_MATCH_NONE;INSTI...     63
# 23         PRESUMED_NEGATED_LONGITUDE;COLLECTION_MATCH_NONE;INSTITUTION_MATCH_FUZZY      3
# 24                       PRESUMED_NEGATED_LONGITUDE;INSTITUTION_COLLECTION_MISMATCH      2
# 25                            RECORDED_DATE_INVALID;INSTITUTION_COLLECTION_MISMATCH      4

# %% [markdown]
# # Descriptions of filtered records

# %% [markdown]
# ### Locations

# %%
shp1 = {'file': '{0}{1}_polygons'.format(outDir, summary_name), 'column': None,
        'alias': 'Occurrence records', 'drawbounds': True, 'linewidth': .75, 'linecolor': 'magenta',
        'fillcolor': None, 'marker':'o'}

# Display occurrence polygons
map_these=[shp1]
    
title="{1} ({0})".format(years, common_name)
try:
    functions.MapShapefilePolygons(map_these=map_these, title=title)
except Exception as e:
    print("Unable to map:  " + str(e))

# %% [markdown]
# ### Years represented

# %%
occ_years = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%Y', occurrenceDate) FROM occurrences").fetchall()]
years = connjup.execute("SELECT years_range FROM gbif_requests WHERE request_id = '{0}'".format(gbif_req_id)).fetchone()[0]
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of records")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# ### Months represented

# %%
occ_months = [int(x[0]) for x in curs_occ.execute("SELECT strftime('%m', occurrenceDate) FROM occurrences").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of records")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# ### Distribution of coordinate uncertainty values

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
maxi = np.max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, maxi, int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("meters")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
occ_cert = [int(x[0]) for x in curs_occ.execute("SELECT coordinateUncertaintyInMeters FROM occurrences").fetchall()]
plt.figure(figsize=(16,4))
plt.boxplot(occ_cert, vert=False)
plt.xlabel("meters")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("meters")
plt.title("Coordinate Uncertainties Below 2km")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainties Below 2km')

# %% [markdown]
# ### Establishment means reported

# %%
establishment = curs_occ.execute("SELECT vals FROM unique_values WHERE field = 'establishment' AND step = 'filter';").fetchall()[0]
for est in establishment:
    est = est.replace('[', '').strip().replace(']', '').replace("'", "")
    print(est)
# Out:
# UNKNOWN, NATIVE

# %% [markdown]
# ### Identification qualifiers included

# %%
quali = curs_occ.execute("SELECT DISTINCT vals FROM unique_values WHERE field = 'IDqualifier' AND step = 'filter';").fetchall()[0]
for q in quali:
    q = q.replace('[', '').strip().replace(']', '').replace("'", "")
    print(q)
# Out:
# A, UNKNOWN

# %% [markdown]
# ### Remarks included

# %%
remarks = curs_occ.execute("SELECT DISTINCT remarks FROM occurrences;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# More than 20 remarks, consult the occurrence database.

# %% [markdown]
# ### Attributes returned for the records in the request (pre-filters)

# %%
fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", conn_occ)#, index_col='index')
fields_summary.index.name = 'Field'
pd.set_option('display.max_rows', 250)
print(fields_summary)
# Out:
#                                   attribute  included(n)  populated(n)
# Field
# 0                    acceptedScientificName         1856          1856
# 1                          acceptedTaxonKey         1856          1856
# 2                              accessRights          211           211
# 3                      associatedReferences           59            59
# 4                       associatedSequences            2             2
# 5                             basisOfRecord         1856          1856
# 6                                  behavior            3             3
# 7                     bibliographicCitation          188           188
# 8                             catalogNumber         1854          1854
# 9                                     class         1856          1856
# 10                                 classKey         1856          1856
# 11                           collectionCode         1854          1854
# 12                             collectionID           34            34
# 13                            collectionKey           50            50
# 14                                continent          260           260
# 15            coordinateUncertaintyInMeters         1413          1413
# 16                                  country         1856          1856
# 17                              countryCode         1856          1856
# 18                                   county          267           267
# 19                                  crawlId         1856          1856
# 20                                  created            2             2
# 21                                datasetID          151           151
# 22                               datasetKey         1856          1856
# 23                              datasetName         1672          1672
# 24                           dateIdentified         1551          1551
# 25                                      day         1846          1846
# 26                          decimalLatitude         1856          1856
# 27                         decimalLongitude         1856          1856
# 28                              disposition          169           169
# 29                        dynamicProperties          101           101
# 30                                elevation           14            14
# 31                        elevationAccuracy            8             8
# 32                             endDayOfYear           60            60
# 33                       establishmentMeans           57            57
# 34                                eventDate         1856          1856
# 35                             eventRemarks            7             7
# 36                                eventTime         1419          1419
# 37                               extensions         1856          1486
# 38                                    facts         1856             0
# 39                                   family         1856          1856
# 40                                familyKey         1856          1856
# 41                              fieldNumber          109           109
# 42                                     gadm         1856          1848
# 43                                   gbifID         1856          1856
# 44                              genericName         1856          1856
# 45                                    genus         1856          1856
# 46                                 genusKey         1856          1856
# 47                            geodeticDatum         1856          1856
# 48                     georeferenceProtocol           99            99
# 49                      georeferenceRemarks           60            60
# 50                      georeferenceSources          176           176
# 51           georeferenceVerificationStatus           80            80
# 52                          georeferencedBy           78            78
# 53                        georeferencedDate            6             6
# 54                                  habitat           11            11
# 55                     higherClassification          174           174
# 56                          higherGeography          188           188
# 57                   hostingOrganizationKey         1856          1856
# 58                  http://unknown.org/nick         1587          1587
# 59     http://unknown.org/occurrenceDetails         1587          1587
# 60              http://unknown.org/recordId            6             6
# 61                         identificationID         1538          1538
# 62                  identificationQualifier            3             3
# 63                    identificationRemarks            5             5
# 64         identificationVerificationStatus            3             3
# 65                             identifiedBy         1677          1677
# 66                          identifiedByIDs         1856            22
# 67                               identifier         1856          1856
# 68                              identifiers         1856             0
# 69                          individualCount          193           193
# 70                      informationWithheld          419           419
# 71                          installationKey         1856          1856
# 72                          institutionCode         1854          1854
# 73                            institutionID          153           153
# 74                           institutionKey          246           246
# 75                              isInCluster         1856          1856
# 76                                   issues         1856          1856
# 77                                      key         1856          1856
# 78                                  kingdom         1856          1856
# 79                               kingdomKey         1856          1856
# 80                                 language          229           229
# 81                              lastCrawled         1856          1856
# 82                          lastInterpreted         1856          1856
# 83                               lastParsed         1856          1856
# 84                                  license         1856          1856
# 85                                lifeStage           28            28
# 86                                 locality          263           263
# 87                      locationAccordingTo            3             3
# 88                               locationID           11            11
# 89                          locationRemarks            9             9
# 90                                    media         1856          1465
# 91                                 modified         1807          1807
# 92                                    month         1856          1856
# 93                             municipality           80            80
# 94                              networkKeys            3             3
# 95                        nomenclaturalCode          158           158
# 96                             occurrenceID         1856          1856
# 97                        occurrenceRemarks          527           527
# 98                         occurrenceStatus         1856          1856
# 99                                    order         1856          1856
# 100                                orderKey         1856          1856
# 101                              organismID            3             3
# 102                     otherCatalogNumbers           42            42
# 103                    ownerInstitutionCode          169           169
# 104                                  phylum         1856          1856
# 105                               phylumKey         1856          1856
# 106                            preparations          186           186
# 107                 previousIdentifications           83            83
# 108                                protocol         1856          1856
# 109                       publishingCountry         1856          1856
# 110                        publishingOrgKey         1856          1856
# 111                            recordNumber           34            34
# 112                              recordedBy         1769          1769
# 113                           recordedByIDs         1856            22
# 114                              references         1824          1824
# 115                               relations         1856             0
# 116                                  rights         1593          1593
# 117                            rightsHolder         1756          1756
# 118                        samplingProtocol            2             2
# 119                          scientificName         1856          1856
# 120                                     sex           14            14
# 121                                 species         1856          1856
# 122                              speciesKey         1856          1856
# 123                         specificEpithet         1856          1856
# 124                          startDayOfYear           75            75
# 125                           stateProvince         1854          1854
# 126                                 taxonID         1595          1595
# 127                                taxonKey         1856          1856
# 128                               taxonRank         1856          1856
# 129                            taxonRemarks           80            80
# 130                         taxonomicStatus         1856          1856
# 131                                    type          237           237
# 132                verbatimCoordinateSystem           29            29
# 133                       verbatimElevation            7             7
# 134                       verbatimEventDate         1648          1648
# 135                        verbatimLocality         1663          1663
# 136                          vernacularName          153           153
# 137                                    year         1856          1856

# %% [markdown]
# ### Runtime

# %%
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:01:16.353832
