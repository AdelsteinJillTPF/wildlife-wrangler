# %% [markdown]
# # GBIF EMAIL/DWCA TEST
#
# The following code can be edited with your notebook's name and run in command line in order to generate output without the input code:
#
# jupyter nbconvert --to html --TemplateExporter.exclude_input=True --output-dir="T:/Temp/" NOTEBOOKNAMEHERE.ipynb

# %%
# Specify some paths and names in the cell below.
config_path = "T:/Data/"  # Path to folder where you saved your wildlifeconfig file.
filter_set_json = "T:/Occurrence_Records/FilterSets/test_dwca_1.json"
taxon_json = "T:/Occurrence_Records/TaxonConcepts/TestCuckoo.json"
query_name = 'DWCA_TEST_4'
ask_eBird = False
ask_GBIF = True

# %%
# Nothing to fill out in the next cell
# %matplotlib inline
import os
import sqlite3
import pprint
import json
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import sys
sys.path.append(config_path)
import wranglerconfig as config
sys.path.append(config.codeDir)
import wrangler_functions as functions

# Define some variables
t1 = datetime.now()
working_directory = config.workDir
username = config.gbif_username
password = config.gbif_password
email = config.gbif_email
EBD_file = config.EBD_file
output_database = working_directory + query_name + '.sqlite'

# Set display options
pd.set_option('display.max_colwidth', 45)
pd.set_option('display.max_rows', 150)

print("Notebook run " + str(t1))
print("Results were saved in " + output_database)
# Out:
# Notebook run 2021-06-24 15:37:17.819924
# Results were saved in T:/Occurrence_Records/DWCA_TEST_4.sqlite

# %% [markdown]
# ## Taxon Concept
# Caution! -- Taxon concept mismatches can cause inclusion of innapropriate records or ommission of useful records.

# %%
your_taxon_id = "test1"
gbif_id = 2427572 
ebird_id = None
detection_distance_m = 200
taxon_polygon = None

# %%
# If a json was provided, use it, otherwise create a new one with info that was provided.
if taxon_json is None:
    # Build a species dictionary
    taxon_info = {"ID": your_taxon_id, "GBIF_ID": gbif_id, "EBIRD_ID": ebird_id, "detection_distance_m": detection_distance_m,
                  "TAXON_EOO": taxon_polygon}

    # Save as json object
    out_file = open(working_directory + your_taxon_id + ".json", "w")  
    json.dump(taxon_info, out_file) 
    out_file.close() 

if taxon_json is not None:
    with open(taxon_json, "r") as f:
        taxon_info = json.load(f)
        f.close()
        
pprint.pprint(taxon_info)
# Out:
# {'EBIRD_ID': 'Yellow-billed Cuckoo',
#  'GBIF_ID': 2496287,
#  'ID': 'TestCuckoo',
#  'TAXON_EOO': 'POLYGON ((-84.09680233298448 36.69265225442667, '
#               '-84.07962135716329 34.5561660300382, -84.07962135716329 '
#               '34.5561660300382, -80.25685423694925 34.65515526072436, '
#               '-81.15026497965096 36.71331438415306, -84.09680233298448 '
#               '36.69265225442667))',
#  'detection_distance_m': 200}

# %% [markdown]
# ## Filter Set
# Specify how you want records filtered and cleaned.  Alternatively, you can load a filter set here by specifying a path in the first cell of this notebook.
#
# To skip a filter, enter "None" without the quotation marks or "".

# %%
filter_set_name = "QuickTest1"
print("Filter set name: " + str(filter_set_name))
# Out:
# Filter set name: QuickTest1

# %% [markdown]
# #### GBIF Request Method

# %%
"""
Whether to get records from GBIF in a darwin core archive.  
"False" uses the GBIF API, which has limitations that may be important.  
"True" requests results be emailed in a darwin core archive.
"""
get_dwca = False 
print("Request a Darwin Core Archive? " + str(get_dwca))
# Out:
# Request a Darwin Core Archive? False

# %% [markdown]
# #### Date Limits
# Notes:

# %%
'''
Enter year and month ranges.  For example, years_range = 2015,2017 and months_range = 3,6
'''
years_range = "1995,2020"
months_range = "1,12"
print("Years: " + str(years_range))
print("Months: " + str(months_range))
# Out:
# Years: 1995,2020
# Months: 1,12

# %% [markdown]
# #### Country
# Notes:

# %%
country = "US"
print("Country: " + str(country))
# Out:
# Country: US

# %% [markdown]
# #### Bounding Box
# Notes:

# %%
'''
Coordinates should correspond to WGS84 (EPSG:4326).  Don't use this option if you specify a query polygon below.
'''
lat_range = None
lon_range = None
print("Latitude range: " + str(lat_range))
print("Longitude range: " + str(lon_range))
# Out:
# Latitude range: None
# Longitude range: None

# %% [markdown]
# #### Area of Interest
# Notes:

# %%
'''
Specify polygons to use for spatial filtering.  
Records with coordinates outside of the polygons will be removed.  
You can specify a geometry for the query and one for the species.  
The species geometry is included to facilitate better handling of taxonomic issues.  
If both are provided, the intersection is calculated and used as the filter.  
The format should be well known text in WGS84 (EPSG 4326), and very importantly, vertices need to be listed counter-clockwise.  
See the ccw_wkt_from_shp() function in wrangler functions for help.
'''
query_polygon = None
print(query_polygon)
# Out:
# None

# %% [markdown]
# #### Taxon EOO
# Notes:

# %%
'''
True or False whether you want to apply the taxon EOO to the filtering.  
If True, removes records with centroids outside of the extent of occurrence geometry you provided in taxon_info.
'''
use_taxon_geometry = False
print("Use taxon extent of occurrence? " + str(use_taxon_geometry))
# Out:
# Use taxon extent of occurrence? False

# %% [markdown]
# #### Geoissue
# Notes:

# %%
'''
Are GBIF records with noted geoissues OK to include? GBIF only.
'''
geoissue = False
print("Records with geoissues OK? " + str(geoissue))
# Out:
# Records with geoissues OK? False

# %% [markdown]
# #### Collections
# Notes:

# %%
'''
List collection codes that you'd like to omit. GBIF only.
'''
collection_codes_omit = None
print("Omit: " + str(collection_codes_omit))
# Out:
# Omit: None

# %% [markdown]
# #### Institutions
# Notes:

# %%
'''
List institution codes that you'd like to omit. GBIF only
'''
institutions_omit = ["MCZ"]
print("Omit: " + str(institutions_omit))
# Out:
# Omit: ['MCZ']

# %% [markdown]
# #### Datasets
# Notes:

# %%
'''
List datasets that you'd like to omit.
'''
datasets_omit = None
print("Omit: " + str(datasets_omit))
# Out:
# Omit: None

# %% [markdown]
# #### Coordinate Uncertainty
# Notes:

# %%
'''
Do you want to remove records without coordinate uncertainty (1) or leave them in the data set (0)?  
Note that eBird records in GBIF (EOD) do not have this and neither do data in the EBD dataset.  
With the EBD, the length of traveling counts is used as a surrogate value.  

max_coordinate_uncertainty must be an integer greater than 0.

default_coordUncertainty -- coordinateUncertaintyInMeters is often not provided.  
Here is an option to use a default.  If you don't want anything entered, set this equal to False (boolean, not string).

A maximum for coordinate uncertainty can also be set in meters.
'''
has_coordinate_uncertainty = False
default_coordUncertainty = 500
max_coordinate_uncertainty = 10000
print("Coordinate uncertainty required? " + str(has_coordinate_uncertainty))
print("Default coordinate uncertainty to use: " + str(default_coordUncertainty))
print("Maximum allowable coordinate uncertainty: " + str(max_coordinate_uncertainty))
# Out:
# Coordinate uncertainty required? False
# Default coordinate uncertainty to use: 500
# Maximum allowable coordinate uncertainty: 10000

# %% [markdown]
# #### Bases
# Notes:

# %%
'''
List bases of records that you want to omit.  GBIF only.
'''
bases_omit = None
print("Omit: " + str(bases_omit))
# Out:
# Omit: None

# %% [markdown]
# #### Sampling Protocols
# Notes:

# %%
'''
List sampling protocols that you would like to omit.
'''
sampling_protocols_omit = None
print("Omit: " + str(sampling_protocols_omit))
# Out:
# Omit: None

# %% [markdown]
# #### Issues
# Notes:

# %%
'''
List issues that you want to omit.  GBIF only.
'''
issues_omit = None
print("Omit: " + str(issues_omit))
# Out:
# Omit: None

# %% [markdown]
# #### Duplicates
# Notes:

# %%
'''
Specify whether duplicates on latitude, longitude, and date should be included.
'''
duplicates_OK = False
print("Allow duplicates? " + str(duplicates_OK))
# Out:
# Allow duplicates? False

# %% [markdown]
# #### Filter Set Summary

# %%
if filter_set_json is None:
    # Build a filter set dictionary
    filter_set = {"name": filter_set_name, "query_polygon": query_polygon, "issues_omit": issues_omit,
                  "sampling_protocols_omit": sampling_protocols_omit, "bases_omit": bases_omit,
                  "has_coordinate_uncertainty": has_coordinate_uncertainty, "geoissue": geoissue,
                  "default_coordUncertainty": default_coordUncertainty,
                  "max_coordinate_uncertainty": max_coordinate_uncertainty,
                  "datasets_omit": datasets_omit, "collection_codes_omit": collection_codes_omit,
                  "institutions_omit": institutions_omit, "geoissue": geoissue, "use_taxon_geometry": use_taxon_geometry,
                  "lat_range": lat_range, "lon_range": lon_range, "country": country, 
                  "years_range": years_range, "months_range": months_range, "duplicates_OK": duplicates_OK, "get_dwca": get_dwca}
    
    # Replace empty strings with None
    for x in filter_set.keys():
        if filter_set[x] == "":
            filter_set[x] = None
    
    # Save as json object
    with open(working_directory + filter_set_name + ".json", "w") as f:
        json.dump(filter_set, f) 
        f.close()
        
if filter_set_json is not None:
    with open(filter_set_json, "r") as f:
        filter_set = json.load(f)
        f.close()
        
    # Replace empty strings with None
    for x in filter_set.keys():
        if filter_set[x] == "":
            filter_set[x] = None
        
pprint.pprint(filter_set)
# Out:
# {'bases_omit': None,
#  'collection_codes_omit': None,
#  'country': 'US',
#  'datasets_omit': None,
#  'default_coordUncertainty': 1000,
#  'duplicates_OK': True,
#  'geoissue': None,
#  'get_dwca': True,
#  'has_coordinate_uncertainty': False,
#  'institutions_omit': None,
#  'issues_omit': None,
#  'lat_range': '30,35',
#  'lon_range': '-89,-75',
#  'max_coordinate_uncertainty': 10000,
#  'months_range': '6,8',
#  'name': 'test_dwca_1',
#  'query_polygon': None,
#  'sampling_protocols_omit': None,
#  'use_taxon_geometry': False,
#  'years_range': '2011,2020'}

# %% [markdown]
# ## Processing

# %%
# Create an output database
functions.build_output_database(output_database)

# Save taxon and filter set info into database
output_db_conn= sqlite3.connect(output_database)
cursor = output_db_conn.cursor()
pd.DataFrame(taxon_info.values(), taxon_info.keys()).applymap(str).to_sql(name='taxon_concept', con=output_db_conn, if_exists='replace')
pd.DataFrame(filter_set.values(), filter_set.keys()).applymap(str).to_sql(name='filter_set', con=output_db_conn, if_exists='replace')
output_db_conn.close()

# %%
# Run the appropriate queries
if ask_eBird == True and ask_GBIF == True:
    # Run eBird query
    ebird_data = functions.get_EBD_records(taxon_info, filter_set, working_directory, EBD_file, query_name)
    # Run GBIF query
    gbif_data = functions.get_GBIF_records(taxon_info, filter_set, query_name, working_directory, username, password, email) 

elif ask_eBird == True and ask_GBIF == False:
    # Run eBird query
    ebird_data = functions.get_EBD_records(taxon_info, filter_set, working_directory, EBD_file, query_name)
    gbif_data = None

elif ask_eBird == False and ask_GBIF == True:
    # Run GBIF query
    gbif_data = functions.get_GBIF_records(taxon_info, filter_set, query_name, working_directory, username, password, email)
    ebird_data = None
# Out:
# Prepared filter set and sorted out geometry constraints: 0:00:00
# 27410 records available
# ['taxonKey = 2496287', 'hasCoordinate = True', 'country = US', 'year >= 2011', 'year <= 2020', 'month >= 6', 'month <= 8', 'decimalLatitude >= 30', 'decimalLatitude <= 35', 'decimalLongitude >= -89', 'decimalLongitude <= -75']
# INFO:Your download key is 0311068-200613084148143
# Downloading Darwin Core Archive zip file for this species .....
# INFO:Download file size: 3721264 bytes
# Download complete: 0:01:25.390659
# Stored GBIF Download DOI etc.: 0:00:00.002015
# Summarized fields returned: 0:00:00.179084
# Prepared GBIF records for processing: 0:00:00.892493

# %%
# Filter out records with undesirable values, locations, and/or duplication.
for x in filter_set.keys():
    if filter_set[x] == "":
        filter_set[x] = None

# %%
functions.process_records(ebird_data=ebird_data, gbif_data=gbif_data, filter_set=filter_set, 
                        taxon_info=taxon_info, working_directory=working_directory, 
                        query_name=query_name)
# Out:
# Prepared data frames for processing: 0:00:00.262233
# Summarized values acquired: 0:00:00.146855
# Number of georeferenced GBIF records: 37
# Applying default coordinate uncertainties for GBIF records
# Prepared records and calculated radii:0:00:00.735254
# Performed filtering: 0:00:00.278367
# DUPLICATES ON LATITUDE, LONGITUDE, DATE-TIME INCLUDED
# Saved summary of filtering results: 0:00:00.363612

# %%
output_db_conn= sqlite3.connect(output_database)
cursor = output_db_conn.cursor()
record_count = cursor.execute("SELECT COUNT(record_id) FROM occurrence_records;").fetchone()
print(str(record_count[0]) + " records were saved in the output database")
# Out:
# 27359 records were saved in the output database

# %% [markdown]
# ## Results of the Filtering

# %% [markdown]
# #### Attributes Returned for GBIF Records
# This count was made before filters were applied

# %%
pd.set_option('display.max_colwidth', 100)
if ask_GBIF == True:
    fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", output_db_conn)
    fields_summary.index.name = 'Field'
    pd.set_option('display.max_rows', 250)
    print(fields_summary.sort_values(by="attribute"))
if ask_GBIF == False:
    print("GBIF was not queried.")
# Out:
#                                  attribute  included(n)  populated(n)
# Field
# 0                                 abstract        27410             0
# 182                      acceptedNameUsage        27410             0
# 175                    acceptedNameUsageID        27410             0
# 230                 acceptedScientificName        27410         27410
# 219                       acceptedTaxonKey        27410         27410
# 1                             accessRights        27410             0
# 2                            accrualMethod        27410             0
# 3                       accrualPeriodicity        27410             0
# 4                            accrualPolicy        27410             0
# 5                              alternative        27410             0
# 89                   associatedOccurrences        27410             0
# 90                     associatedOrganisms        27410             0
# 81                    associatedReferences        27410             0
# 82                     associatedSequences        27410             0
# 83                          associatedTaxa        27410             1
# 6                                 audience        27410             0
# 7                                available        27410             0
# 62                           basisOfRecord        27410         27410
# 164                                    bed        27410             0
# 76                                behavior        27410             2
# 8                    bibliographicCitation        27410             0
# 67                           catalogNumber        27410         27410
# 191                                  class        27410         27410
# 222                               classKey        27410         27410
# 59                          collectionCode        27410         27410
# 56                            collectionID        27410             0
# 9                               conformsTo        27410             0
# 115                              continent        27410             0
# 10                             contributor        27410             0
# 134                    coordinatePrecision        27410             0
# 133          coordinateUncertaintyInMeters        27410            37
# 119                            countryCode        27410         27410
# 121                                 county        27410         27366
# 11                                coverage        27410             0
# 12                                 created        27410             0
# 13                                 creator        27410             0
# 64                     dataGeneralizations        27410             0
# 57                               datasetID        27410             0
# 205                             datasetKey        27410         27410
# 60                             datasetName        27410            42
# 14                                    date        27410             0
# 15                            dateAccepted        27410             0
# 16                         dateCopyrighted        27410             0
# 169                         dateIdentified        27410            41
# 17                           dateSubmitted        27410             0
# 103                                    day        27410         27410
# 131                        decimalLatitude        27410         27410
# 132                       decimalLongitude        27410         27410
# 210                                  depth        27410             0
# 211                          depthAccuracy        27410             0
# 18                             description        27410             0
# 80                             disposition        27410             0
# 212                   distanceAboveSurface        27410             0
# 213           distanceAboveSurfaceAccuracy        27410             0
# 65                       dynamicProperties        27410             0
# 156               earliestAgeOrLowestStage        27410             0
# 148            earliestEonOrLowestEonothem        27410             0
# 154            earliestEpochOrLowestSeries        27410             0
# 150             earliestEraOrLowestErathem        27410             0
# 152           earliestPeriodOrLowestSystem        27410             0
# 19                          educationLevel        27410             0
# 208                              elevation        27410             0
# 209                      elevationAccuracy        27410             0
# 100                           endDayOfYear        27410             0
# 77                      establishmentMeans        27410             0
# 97                               eventDate        27410         27410
# 94                                 eventID        27410             0
# 111                           eventRemarks        27410             0
# 98                               eventTime        27410            41
# 20                                  extent        27410             0
# 193                                 family        27410         27410
# 224                              familyKey        27410         27410
# 110                             fieldNotes        27410             2
# 96                             fieldNumber        27410             0
# 139                           footprintSRS        27410             0
# 140                    footprintSpatialFit        27410             0
# 138                           footprintWKT        27410             0
# 21                                  format        27410             0
# 162                              formation        27410             0
# 229                            genericName        27410         27410
# 194                                  genus        27410         27410
# 225                               genusKey        27410         27410
# 249                          geodeticDatum        27410         27410
# 147                    geologicalContextID        27410             0
# 143                   georeferenceProtocol        27410             0
# 146                    georeferenceRemarks        27410             0
# 144                    georeferenceSources        27410             0
# 145         georeferenceVerificationStatus        27410             0
# 141                        georeferencedBy        27410             0
# 142                      georeferencedDate        27410             0
# 161                                  group        27410             0
# 105                                habitat        27410             0
# 216                          hasCoordinate        27410         27410
# 22                               hasFormat        27410             0
# 217                    hasGeospatialIssues        27410         27410
# 23                                 hasPart        27410             0
# 24                              hasVersion        27410             0
# 188                   higherClassification        27410             2
# 114                        higherGeography        27410             0
# 113                      higherGeographyID        27410             0
# 159            highestBiostratigraphicZone        27410             0
# 165                       identificationID        27410            41
# 166                identificationQualifier        27410             0
# 170               identificationReferences        27410             0
# 172                  identificationRemarks        27410             0
# 171       identificationVerificationStatus        27410             0
# 168                           identifiedBy        27410            41
# 239                         identifiedByID        27410             0
# 25                              identifier        27410         27410
# 70                         individualCount        27410         26874
# 63                     informationWithheld        27410             2
# 197                   infraspecificEpithet        27410             0
# 58                         institutionCode        27410         27408
# 55                           institutionID        27410             0
# 26                     instructionalMethod        27410             0
# 27                              isFormatOf        27410             0
# 28                                isPartOf        27410             0
# 29                          isReferencedBy        27410             0
# 30                            isReplacedBy        27410             0
# 31                            isRequiredBy        27410             0
# 32                             isVersionOf        27410             0
# 118                                 island        27410             0
# 117                            islandGroup        27410             0
# 214                                  issue        27410            42
# 33                                  issued        27410             0
# 248                    iucnRedListCategory        27410         27410
# 189                                kingdom        27410         27410
# 220                             kingdomKey        27410         27410
# 34                                language        27410             0
# 235                            lastCrawled        27410         27410
# 207                        lastInterpreted        27410         27410
# 234                             lastParsed        27410         27410
# 157                latestAgeOrHighestStage        27410             0
# 149             latestEonOrHighestEonothem        27410             0
# 155             latestEpochOrHighestSeries        27410             0
# 151              latestEraOrHighestErathem        27410             0
# 153            latestPeriodOrHighestSystem        27410             0
# 240                              level0Gid        27410         27360
# 241                             level0Name        27410         27360
# 242                              level1Gid        27410         27360
# 243                             level1Name        27410         27360
# 244                              level2Gid        27410         27360
# 245                             level2Name        27410         27360
# 246                              level3Gid        27410             0
# 247                             level3Name        27410             0
# 35                                 license        27410         27410
# 74                               lifeStage        27410             1
# 160                lithostratigraphicTerms        27410             0
# 123                               locality        27410         27368
# 129                    locationAccordingTo        27410             0
# 112                             locationID        27410             0
# 130                        locationRemarks        27410             0
# 158             lowestBiostratigraphicZone        27410             0
# 93                        materialSampleID        27410             0
# 128    maximumDistanceAboveSurfaceInMeters        27410             0
# 215                              mediaType        27410            43
# 36                                mediator        27410             0
# 37                                  medium        27410             0
# 163                                 member        27410             0
# 127    minimumDistanceAboveSurfaceInMeters        27410             0
# 38                                modified        27410            42
# 102                                  month        27410         27410
# 122                           municipality        27410             0
# 185                        nameAccordingTo        27410             0
# 178                      nameAccordingToID        27410             0
# 186                        namePublishedIn        27410             0
# 179                      namePublishedInID        27410             0
# 187                    namePublishedInYear        27410             0
# 201                      nomenclaturalCode        27410             2
# 203                    nomenclaturalStatus        27410             0
# 66                            occurrenceID        27410         27410
# 85                       occurrenceRemarks        27410             7
# 78                        occurrenceStatus        27410         27410
# 192                                  order        27410         27410
# 223                               orderKey        27410         27410
# 86                              organismID        27410             0
# 87                            organismName        27410             0
# 71                        organismQuantity        27410             0
# 72                    organismQuantityType        27410             0
# 92                         organismRemarks        27410             0
# 88                           organismScope        27410             0
# 184                      originalNameUsage        27410             0
# 177                    originalNameUsageID        27410             0
# 84                     otherCatalogNumbers        27410             0
# 61                    ownerInstitutionCode        27410             0
# 95                           parentEventID        27410             0
# 183                        parentNameUsage        27410             0
# 176                      parentNameUsageID        27410             0
# 190                                 phylum        27410         27410
# 221                              phylumKey        27410         27410
# 135                  pointRadiusSpatialFit        27410             0
# 79                            preparations        27410             0
# 91                 previousIdentifications        27410             0
# 233                               protocol        27410         27410
# 39                              provenance        27410             0
# 40                               publisher        27410             0
# 206                      publishingCountry        27410         27410
# 68                            recordNumber        27410             0
# 69                              recordedBy        27410         27410
# 238                           recordedByID        27410             0
# 41                              references        27410            44
# 42                                relation        27410             0
# 237               relativeOrganismQuantity        27410             0
# 236                            repatriated        27410         27410
# 43                                replaces        27410             0
# 75                   reproductiveCondition        27410             0
# 44                                requires        27410             0
# 45                                  rights        27410            42
# 46                            rightsHolder        27410            44
# 109                         sampleSizeUnit        27410             0
# 108                        sampleSizeValue        27410             0
# 107                         samplingEffort        27410             0
# 106                       samplingProtocol        27410             0
# 181                         scientificName        27410         27410
# 174                       scientificNameID        27410             0
# 73                                     sex        27410             0
# 47                                  source        27410             0
# 48                                 spatial        27410             0
# 228                                species        27410         27410
# 227                             speciesKey        27410         27410
# 196                        specificEpithet        27410         27410
# 99                          startDayOfYear        27410             0
# 120                          stateProvince        27410         27408
# 195                               subgenus        27410             0
# 226                            subgenusKey        27410             0
# 49                                 subject        27410             0
# 50                         tableOfContents        27410             0
# 180                         taxonConceptID        27410             0
# 173                                taxonID        27410            42
# 218                               taxonKey        27410         27410
# 198                              taxonRank        27410         27410
# 204                           taxonRemarks        27410             0
# 202                        taxonomicStatus        27410         27410
# 51                                temporal        27410             0
# 52                                   title        27410             0
# 53                                    type        27410             0
# 167                             typeStatus        27410             0
# 232                           typifiedName        27410             0
# 54                                   valid        27410             0
# 136               verbatimCoordinateSystem        27410             0
# 126                          verbatimDepth        27410             0
# 125                      verbatimElevation        27410             2
# 104                      verbatimEventDate        27410            44
# 124                       verbatimLocality        27410            42
# 137                            verbatimSRS        27410             0
# 231                 verbatimScientificName        27410         27410
# 199                      verbatimTaxonRank        27410             0
# 200                         vernacularName        27410         27368
# 116                              waterBody        27410             0
# 101                                   year        27410         27410

# %% [markdown]
# #### Attributes Returned for eBird Records
# This count was made before filters were applied

# %%
if ask_eBird == True:
    fields_summary = pd.read_sql("SELECT * FROM ebird_fields_returned", output_db_conn)
    fields_summary.index.name = 'Field'
    pd.set_option('display.max_rows', 250)
    print(fields_summary)
if ask_eBird == False:
    print("No eBird Basic Dataset was queried.")
# Out:
# No eBird Basic Dataset was queried.

# %% [markdown]
# #### Sources

# %%
pd.set_option('display.max_colwidth', 31)
sources = pd.read_sql(sql="SELECT * FROM sources;", con=output_db_conn)
print(sources[['institutionID', 'collectionCode', 'datasetName', 'acquired', 'removed', 'retained']])
# Out:
#    institutionID  collectionCode                     datasetName  acquired  removed  retained
# 0            nan     Bird sounds                             nan         2        0         2
# 1            nan           EBIRD                             nan     27145       47     27098
# 2            nan        EBIRD_AK                             nan         3        0         3
# 3            nan    EBIRD_ATL_VA                             nan         1        0         1
# 4            nan    EBIRD_ATL_WI                             nan         1        0         1
# 5            nan        EBIRD_AU                             nan         1        0         1
# 6            nan       EBIRD_BRA                             nan        65        0        65
# 7            nan  EBIRD_CAMERICA                             nan        15        0        15
# 8            nan       EBIRD_CAN                             nan        11        0        11
# 9            nan        EBIRD_CB                             nan         5        0         5
# 10           nan        EBIRD_CL                             nan        13        0        13
# 11           nan       EBIRD_ESP                             nan         5        0         5
# 12           nan        EBIRD_ME                             nan         3        0         3
# 13           nan       EBIRD_MEX                             nan        25        0        25
# 14           nan        EBIRD_MO                             nan         6        0         6
# 15           nan        EBIRD_NH                             nan         1        0         1
# 16           nan        EBIRD_NJ                             nan         2        0         2
# 17           nan        EBIRD_PA                             nan         2        0         2
# 18           nan       EBIRD_PNW                             nan         6        0         6
# 19           nan        EBIRD_PR                             nan         1        0         1
# 20           nan        EBIRD_QC                             nan         1        0         1
# 21           nan        EBIRD_TX                             nan        15        0        15
# 22           nan        EBIRD_VA                             nan         1        0         1
# 23           nan      EBIRD_VINS                             nan         1        0         1
# 24           nan        EBIRD_WI                             nan        37        0        37
# 25           nan    Observations  iNaturalist research-grade ...        42        4        38

# %% [markdown]
# #### Bases

# %%
bases = pd.read_sql(sql="SELECT * FROM attribute_value_counts WHERE attribute = 'basisOfRecord';", con=output_db_conn)
print(bases[['value', 'acquired', 'removed', 'retained']])
# Out:
#                value  acquired  removed  retained
# 0  HUMAN_OBSERVATION     27410       51     27359

# %% [markdown]
# #### Protocols

# %%
protocols = pd.read_sql(sql="SELECT * FROM attribute_value_counts WHERE attribute = 'samplingProtocol';", con=output_db_conn)
if protocols.empty == True:
    print("No protocols were documented.")
if protocols.empty == False:
    print(protocols[['value', 'acquired', 'removed', 'retained']])
# Out:
#   value  acquired  removed  retained
# 0   nan     27410       51     27359

# %% [markdown]
# #### Issues

# %%
pd.set_option('display.max_colwidth', 90)
issues = pd.read_sql(sql="SELECT * FROM attribute_value_counts WHERE attribute = 'issues';", con=output_db_conn)
if issues.empty == True:
    print("No issues were documented.")
if issues.empty == False:
    print(issues[['value', 'acquired', 'removed', 'retained']])
# Out:
#                                                                                    value  acquired  removed  retained
# 0                                        COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84        34        2        32
# 1  COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_UNCERTAINTY_METERS_INVALID         2        0         2
# 2                                                           GEODETIC_DATUM_ASSUMED_WGS84         6        2         4
# 3                                                                                    nan     27368       47     27321

# %% [markdown]
# #### Establishment Means

# %%
establishment = pd.read_sql(sql="SELECT * FROM attribute_value_counts WHERE attribute = 'establishmentMeans';", con=output_db_conn)
if establishment.empty == True:
    print("No establishment means were reported.")
if establishment.empty == False:
    print(establishment[['value', 'acquired', 'removed', 'retained']])
# Out:
#   value  acquired  removed  retained
# 0   nan     27410       51     27359

# %% [markdown]
# #### Identification Qualifiers

# %%
qualifications = pd.read_sql(sql="SELECT * FROM attribute_value_counts WHERE attribute = 'identificationQualifers';", con=output_db_conn)
if qualifications.empty == True:
    print("No identification qualifiers were reported.")
if qualifications.empty == False:
    print(establishment[['value', 'acquired', 'removed', 'retained']])
# Out:
# No identification qualifiers were reported.

# %% [markdown]
# ## Descriptions of Retained Records

# %% [markdown]
# #### Locations

# %%
# Get the record coordinates as a data frame
record_coordinates = (pd.read_sql("""SELECT decimalLatitude, decimalLongitude, radius_m
                                     FROM occurrence_records""",
                                  con=output_db_conn)
                      .astype({'decimalLongitude': 'float', 'decimalLatitude': 'float',
                               'radius_m': 'float'}))

# Make the data frame spatial
gdf = gpd.GeoDataFrame(record_coordinates, geometry=gpd.points_from_xy(record_coordinates['decimalLongitude'],
                                                   record_coordinates['decimalLatitude']))

# Set the coordinate reference system
gdf.crs={'init' :'epsg:4326'}

# Create world map <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
base = world.plot(figsize=(12,12), color = 'darkkhaki')
gdf.plot(ax=base, marker='o', color='k', markersize=5)
plt.show()

# Create USA map <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
if filter_set["country"] == "US":
    usa_bbox = np.array([-124.725839,   24.498131,  -66.949895,   49.384358])
    fig, ax = plt.subplots(figsize=(12,12))
    ax.set_xlim(([usa_bbox[0],  usa_bbox[2]]))
    ax.set_ylim(([usa_bbox[1],  usa_bbox[3]]))
    world.plot(ax=ax, color='darkkhaki')
    gdf.plot(ax=ax, marker='o', color='k', markersize=5)
    plt.show()

# Create coordinate extent map <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
os.chdir(config.codeDir)
states = gpd.read_file(os.getcwd() + '/data/us_states.shp')

# Reproject states and record coordinates to facilitate buffering
states = states.to_crs(epsg=5070)
footprints = gdf.to_crs(epsg=5070)

# Buffer points for record footprints
footprints['footprint']=footprints.apply(lambda x: x.geometry.buffer(x.radius_m), axis=1)
footprints.set_geometry(col='footprint', inplace=True, drop=True)

# Map the buffered points/footprints
fig, ax = plt.subplots(figsize=(12,12))
coordinate_bbox = footprints.geometry.total_bounds
ax.set_xlim(([coordinate_bbox[0],  coordinate_bbox[2]]))
ax.set_ylim(([coordinate_bbox[1],  coordinate_bbox[3]]))
states.plot(ax=ax, color = 'darkkhaki')
footprints.boundary.plot(ax=ax, color='k')
plt.show()

# Cleanup
del footprints, gdf
# Out:
# T:\Miniconda3\envs\pygbif_test\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %% [markdown]
# #### Years Represented

# %%
occ_years = [int(x[0]) for x in cursor.execute("SELECT strftime('%Y', eventDate) FROM occurrence_records").fetchall()]
years = filter_set['years_range']
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of records")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# #### Months Represented

# %%
occ_months = [int(x[0]) for x in cursor.execute("SELECT strftime('%m', eventDate) FROM occurrence_records").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of records")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# #### Distribution of Coordinate Uncertainty Values for Retained Records

# %%
try:
    occ_cert = [float(x[0]) for x in cursor.execute("SELECT coordinateUncertaintyInMeters FROM occurrence_records WHERE coordinateUncertaintyInMeters > 0.0;").fetchall()]
    maxi = max(occ_cert)
    plt.figure(figsize=(16,4))
    plt.hist(occ_cert, bins=50, color="r")
    plt.xticks(range(0, int(maxi), int(maxi/50)), rotation=90)
    plt.ylabel("number of records")
    plt.xlabel("meters")
    plt.title("Reported Coordinate Uncertainties")
except:
    print("No coordinate uncertanties values were reported.")

# %%
try:
    plt.figure(figsize=(11,4))
    plt.boxplot(occ_cert, vert=False)
    plt.xlabel("meters")
    plt.title("Reported Coordinate Uncertainties")
except:
    print("No coordinate uncertanties values were reported.")

# %%
try:
    rng_max = 2000
    occ_cert2 = [x for x in occ_cert if x <= rng_max]
    plt.figure(figsize=(12,4))
    plt.hist(occ_cert2, bins=30, color="m", align='mid')
    plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
    plt.ylabel("number of records")
    plt.xlabel("meters")
    plt.title("Reported Coordinate Uncertainties Below 2km")
except:
    print("No coordinate uncertanties values were reported.")

# %% [markdown]
# #### Distribution of Point-radius Values for Retained Records

# %%
occ_cert = [float(x[0]) for x in cursor.execute("SELECT radius_m FROM occurrence_records;").fetchall()]
plt.figure(figsize=(11,4))
plt.boxplot(occ_cert, vert=False)
plt.xlabel("meters")
plt.title("Compiled Point-radius Buffer Lengths")
# Out:
# Text(0.5, 1.0, 'Compiled Point-radius Buffer Lengths')

# %% [markdown]
# #### Distribution of Nominal Coordinate Precisions for Retained Records

# %%
occ_cert = [float(x[0]) for x in cursor.execute("SELECT nominal_xy_precision FROM occurrence_records;").fetchall()]
plt.figure(figsize=(11,4))
plt.boxplot(occ_cert, vert=False)
plt.xlabel("meters")
plt.title("Nominal Precisions of Coordinates")
# Out:
# Text(0.5, 1.0, 'Nominal Precisions of Coordinates')

# %% [markdown]
# #### Remarks

# %%
print("General remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT general_remarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# General remarks:
# nan

# %%
print("Event remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT eventRemarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# Event remarks:
# nan

# %%
print("Occurrence remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT occurrenceRemarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# Occurrence remarks:
# nan
# Window kill
# Yellow-billed Cuckoo Washington County, Florida 7-15-11
# Need headphones to properly hear this call - it's a soft, rapid, repetitive cooing sound. In the second audio file, you'll hear a red-bellied woodpecker and my phone vibrating. This bird call is much quieter than those sounds. I believe it's a bird, but not sure. Closest match I could find is ground dove (Columbina passerina), but I think it's not that species - the call is too rapid a little different in pitch. Help - it's driving me crazy, been hearing it for weeks now. Yesterday I'm pretty sure I heard a call-and-response from two of these. Both were located near small creeks through young, mixed hardwood forest.
# Adults and juveniles in trees above the Goose Overlook Observation deck
# on nest
# recently fledged juvenile

# %%
print("Location remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT locationRemarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# Location remarks:
# nan

# %%
print("Identified remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT general_remarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# Identified remarks:
# nan

# %%
print("Georeference remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT georeferenceRemarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# Georeference remarks:
# nan

# %% [markdown]
# ## Citations
# #### eBird

# %%
if ask_eBird == True:
    with open(config.EBD_file[:-22] + "recommended_citation.txt", "r") as reference:
        print(reference.readlines()[0])
else:
    print("No eBird Basic Dataset was queried")
# Out:
# No eBird Basic Dataset was queried

# %% [markdown]
# #### GBIF

# %%
if ask_GBIF == True:
    if get_dwca == True:
        print("Citations-- ")
        print(cursor.execute("SELECT citations FROM GBIF_download_info").fetchall()[0][0])
    else:
        print("Set 'get_dwca' to True to acquire a list of citations")
if ask_GBIF == False:
    print("GBIF was not queried.")
# Out:
# Set 'get_dwca' to True to acquire a list of citations

# %%
if ask_GBIF == True:
    if get_dwca == True:
        print("Rights-- ")
        print(output_db_conn.execute("SELECT rights FROM GBIF_download_info").fetchall()[0][0])
    else:
        print("Set 'get_dwca' to True to see the rights")
if ask_GBIF == False:
    print("GBIF was not queried.")
# Out:
# Set 'get_dwca' to True to see the rights

# %%
if ask_GBIF == True:
    if get_dwca == True:
        print("DOI-- ")
        doi = output_db_conn.execute("SELECT doi FROM GBIF_download_info").fetchall()[0][0]
        print("https://doi.org/" + doi)
    else:
        print("Set 'get_dwca' to True to perform a search with a doi assigned")
if ask_GBIF == False:
    print("GBIF was not queried.")
# Out:
# Set 'get_dwca' to True to perform a search with a doi assigned

# %%
if ask_GBIF == True:
    if get_dwca == True:
        print("GBIF download key-- ")
        print(output_db_conn.execute("SELECT download_key FROM GBIF_download_info").fetchall()[0][0])
    else:
        print("Set 'get_dwca' to True to perform a search with a download key assigned")
if ask_GBIF == False:
    print("GBIF was not queried")
# Out:
# Set 'get_dwca' to True to perform a search with a download key assigned

# %% [markdown]
# ## Runtime

# %%
output_db_conn.close()
del cursor
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:01:53.083330

# %%
functions.verify_results(output_database)
# Out:
# T:\Miniconda3\envs\pygbif_test\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
