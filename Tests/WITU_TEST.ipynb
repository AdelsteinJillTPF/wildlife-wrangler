# %% [markdown]
# # Wild Turkey Test
#
# The following code can be edited with your notebook's name and run in command line in order to generate output without the input code:
#
# jupyter nbconvert --to html --TemplateExporter.exclude_input=True --output-dir="T:/Temp/" WITU_TEST.ipynb

# %%
# Specify some paths and names in the cell below.
config_path = "T:/Data/"  # Path to folder where you saved your wildlifeconfig file.
filter_set_json = None
taxon_json = None
query_name = 'WITU_TEST'
ask_eBird = True
ask_GBIF = True

# %%
# Nothing to fill out in this cell
# %matplotlib inline
import os
import sqlite3
import pprint
import json
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import sys
sys.path.append(config_path)
import wranglerconfig as config
sys.path.append(config.codeDir)
import wrangler_functions as functions

# Define some variables
t1 = datetime.now()
working_directory = config.workDir
username = config.gbif_username
password = config.gbif_password
email = config.gbif_email
EBD_file = config.EBD_file
output_database = working_directory + query_name + '.sqlite'

# Set display options
pd.set_option('display.width', 600)
pd.set_option('display.max_colwidth', 75)
pd.set_option('display.max_rows', 150)

print("Notebook run " + str(t1))
print("Results were saved in " + output_database)
# Out:
# Notebook run 2021-04-29 15:09:22.626177
# Results were saved in T:/Occurrence_Records/WITU_TEST.sqlite

# %% [markdown]
# ## Taxon Concept
# Caution! -- Taxon concept mismatches can cause inclusion of innapropriate records or ommission of useful records.

# %%
your_taxon_id = "bwitux0"
gbif_id = 9606290 
ebird_id = "Wild Turkey"
detection_distance_m = 300
taxon_polygon = None

# %%
# If a json was provided, use it, otherwise create a new one with info that was provided.
if taxon_json is None:
    # Build a species dictionary
    taxon_info = {"ID": your_taxon_id, "GBIF_ID": gbif_id, "EBIRD_ID": ebird_id, "detection_distance_m": detection_distance_m,
                  "TAXON_EOO": taxon_polygon}

    # Save as json object
    out_file = open(working_directory + your_taxon_id + ".json", "w")  
    json.dump(taxon_info, out_file) 
    out_file.close() 

if taxon_json is not None:
    with open(taxon_json, "r") as f:
        taxon_info = json.load(f)
        f.close()
        
pprint.pprint(taxon_info)
# Out:
# {'EBIRD_ID': 'Wild Turkey',
#  'GBIF_ID': 9606290,
#  'ID': 'bwitux0',
#  'TAXON_EOO': None,
#  'detection_distance_m': 300}

# %% [markdown]
# ## Filter Set
# Specify how you want records filtered and cleaned.  Alternatively, you can load a filter set here by specifying a path in the first cell of this notebook.
#
# To skip a filter, enter "None" without the quotation marks or "".

# %%
filter_set_name = "GAP_1"
print("Filter set name: " + str(filter_set_name))
# Out:
# Filter set name: GAP_1

# %% [markdown]
# #### GBIF Request Method

# %%
"""
Whether to get records from GBIF in a darwin core archive.  
"False" uses the GBIF API, which has limitations that may be important.  
"True" requests results be emailed in a darwin core archive.
"""
get_dwca = True 
print("Request a Darwin Core Archive? " + str(get_dwca))
# Out:
# Request a Darwin Core Archive? True

# %% [markdown]
# #### Date Limits
# Notes:

# %%
'''
Enter year and month ranges.  For example, years_range = 2015,2017 and months_range = 3,6
'''
years_range = "2001,2021"
months_range = "1,12"
print("Years: " + str(years_range))
print("Months: " + str(months_range))
# Out:
# Years: 2001,2021
# Months: 1,12

# %% [markdown]
# #### Country
# Notes:

# %%
country = "US"
print("Country: " + country)
# Out:
# Country: US

# %% [markdown]
# #### Bounding Box
# Notes:

# %%
'''
Coordinates should correspond to WGS84 (EPSG:4326).  Don't use this option if you specify a query polygon below.
'''
lat_range = "18,50"
lon_range = "-150,-67"
print("Latitude range: " + lat_range)
print("Longitude range: " + lon_range)
# Out:
# Latitude range: 18,50
# Longitude range: -150,-67

# %% [markdown]
# #### Area of Interest
# Notes:

# %%
'''
Specify polygons to use for spatial filtering.  
Records with coordinates outside of the polygons will be removed.  
You can specify a geometry for the query and one for the species.  
The species geometry is included to facilitate better handling of taxonomic issues.  
If both are provided, the intersection is calculated and used as the filter.  
The format should be well known text in WGS84 (EPSG 4326), and very importantly, vertices need to be listed counter-clockwise.  
See the ccw_wkt_from_shp() function in wrangler functions for help.
'''
query_polygon = None
print(query_polygon)
# Out:
# None

# %% [markdown]
# #### Taxon EOO
# Notes:

# %%
'''
True or False whether you want to apply the taxon EOO to the filtering.  
If True, removes records with centroids outside of the extent of occurrence geometry you provided in taxon_info.
'''
use_taxon_geometry = False
print("Use taxon extent of occurrence? " + str(use_taxon_geometry))
# Out:
# Use taxon extent of occurrence? False

# %% [markdown]
# #### Geoissue
# Notes:

# %%
'''
Are GBIF records with noted geoissues OK to include? GBIF only.
'''
geoissue = None
print("Records with geoissues OK? " + str(geoissue))
# Out:
# Records with geoissues OK? None

# %% [markdown]
# #### Collections
# Notes:

# %%
'''
List collection codes that you'd like to omit. GBIF only.
'''
collection_codes_omit = None
print("Omit: " + str(collection_codes_omit))
# Out:
# Omit: None

# %% [markdown]
# #### Institutions
# Notes:

# %%
'''
List institution codes that you'd like to omit. GBIF only
'''
institutions_omit = None
print("Omit: " + str(institutions_omit))
# Out:
# Omit: None

# %% [markdown]
# #### Datasets
# Notes:

# %%
'''
List datasets that you'd like to omit.
'''
datasets_omit = None
print("Omit: " + str(datasets_omit))
# Out:
# Omit: None

# %% [markdown]
# #### Coordinate Uncertainty
# Notes:

# %%
'''
Do you want to remove records without coordinate uncertainty (True) or leave them in the data set (False)?  
Note that eBird records in GBIF (EOD) do not have this and neither do data in the EBD dataset.  
With the EBD, the length of traveling counts is used as a surrogate value.  

max_coordinate_uncertainty must be an integer greater than 0.

default_coordUncertainty -- coordinateUncertaintyInMeters is often not provided.  
Here is an option to use a default.  If you don't want anything entered, set this equal to False (boolean, not string).

A maximum for coordinate uncertainty can also be set in meters.
'''
has_coordinate_uncertainty = False
default_coordUncertainty = 2000
max_coordinate_uncertainty = 10000
print("Coordinate uncertainty required? " + str(has_coordinate_uncertainty))
print("Default coordinate uncertainty to use: " + str(default_coordUncertainty))
print("Maximum allowable coordinate uncertainty: " + str(max_coordinate_uncertainty))
# Out:
# Coordinate uncertainty required? False
# Default coordinate uncertainty to use: 2000
# Maximum allowable coordinate uncertainty: 10000

# %% [markdown]
# #### Bases
# Notes:

# %%
'''
List bases of records that you want to omit.  GBIF only.
'''
bases_omit = ["PRESERVED_SPECIMEN"]
print("Omit: " + str(bases_omit))
# Out:
# Omit: ['PRESERVED_SPECIMEN']

# %% [markdown]
# #### Sampling Protocols
# Notes:

# %%
'''
List sampling protocols that you would like to omit.
'''
sampling_protocols_omit = ["eBird Pelagic Protocol"]
print("Omit: " + str(sampling_protocols_omit))
# Out:
# Omit: ['eBird Pelagic Protocol']

# %% [markdown]
# #### Issues
# Notes:

# %%
'''
List issues that you want to omit.  GBIF only.
'''
issues_omit = ["COORDINATE_UNCERTAINTY_METERS_INVALID"]
print("Omit: " + str(issues_omit))
# Out:
# Omit: ['COORDINATE_UNCERTAINTY_METERS_INVALID']

# %% [markdown]
# #### Duplicates
# Notes:

# %%
'''
Specify whether duplicates on latitude, longitude, and date should be included.
'''
duplicates_OK = True
print("Allow duplicates? " + str(duplicates_OK))
# Out:
# Allow duplicates? True

# %% [markdown]
# #### Filter Set Summary

# %%
if filter_set_json is None:
    # Build a filter set dictionary
    filter_set = {"name": filter_set_name, "query_polygon": query_polygon, "issues_omit": issues_omit,
                  "sampling_protocols_omit": sampling_protocols_omit, "bases_omit": bases_omit,
                  "has_coordinate_uncertainty": has_coordinate_uncertainty, "geoissue": geoissue,
                  "default_coordUncertainty": default_coordUncertainty,
                  "max_coordinate_uncertainty": max_coordinate_uncertainty,
                  "datasets_omit": datasets_omit, "collection_codes_omit": collection_codes_omit,
                  "institutions_omit": institutions_omit, "geoissue": geoissue, "use_taxon_geometry": use_taxon_geometry,
                  "lat_range": lat_range, "lon_range": lon_range, "country": country, 
                  "years_range": years_range, "months_range": months_range, "duplicates_OK": duplicates_OK, "get_dwca": get_dwca}
    
    # Replace empty strings with None
    for x in filter_set.keys():
        if filter_set[x] == "":
            filter_set[x] = None
    
    # Save as json object
    with open(working_directory + filter_set_name + ".json", "w") as f:
        json.dump(filter_set, f) 
        f.close()
        
if filter_set_json is not None:
    with open(filter_set_json, "r") as f:
        filter_set = json.load(f)
        f.close()
        
    # Replace empty strings with None
    for x in filter_set.keys():
        if filter_set[x] == "":
            filter_set[x] = None
        
pprint.pprint(filter_set)
# Out:
# {'bases_omit': ['PRESERVED_SPECIMEN'],
#  'collection_codes_omit': None,
#  'country': 'US',
#  'datasets_omit': None,
#  'default_coordUncertainty': 2000,
#  'duplicates_OK': True,
#  'geoissue': None,
#  'get_dwca': True,
#  'has_coordinate_uncertainty': False,
#  'institutions_omit': None,
#  'issues_omit': ['COORDINATE_UNCERTAINTY_METERS_INVALID'],
#  'lat_range': '18,50',
#  'lon_range': '-150,-67',
#  'max_coordinate_uncertainty': 10000,
#  'months_range': '1,12',
#  'name': 'GAP_1',
#  'query_polygon': None,
#  'sampling_protocols_omit': ['eBird Pelagic Protocol'],
#  'use_taxon_geometry': False,
#  'years_range': '2001,2021'}

# %% [markdown]
# ## Processing

# %%
# Create an output database
functions.build_output_database(output_database)

# Save taxon and filter set info into database
output_db_conn= sqlite3.connect(output_database)
cursor = output_db_conn.cursor()
pd.DataFrame(taxon_info.values(), taxon_info.keys()).applymap(str).to_sql(name='taxon_concept', con=output_db_conn, if_exists='replace')
pd.DataFrame(filter_set.values(), filter_set.keys()).applymap(str).to_sql(name='filter_set', con=output_db_conn, if_exists='replace')
output_db_conn.close()

# %%
# Run the appropriate queries
if ask_eBird == True and ask_GBIF == True:
    # Run eBird query
    ebird_data = functions.get_EBD_records(taxon_info, filter_set, working_directory, EBD_file, query_name)
    # Run GBIF query
    gbif_data = functions.get_GBIF_records(taxon_info, filter_set, query_name, working_directory, username, password, email) 

elif ask_eBird == True and ask_GBIF == False:
    # Run eBird query
    ebird_data = functions.get_EBD_records(taxon_info, filter_set, working_directory, EBD_file, query_name)
    gbif_data = None

elif ask_eBird == False and ask_GBIF == True:
    # Run GBIF query
    gbif_data = functions.get_GBIF_records(taxon_info, filter_set, query_name, working_directory, username, password, email)
    ebird_data = None
# Out:
# Ran EBD query with Auk: 0:31:35.476309
# Calculated the spatial filter polygon: 0:00:06.537155
# Applied spatial filter: 0:00:00
# Summarized fields returned: 0:00:00.647560
# Prepared the eBird records for processing: 0:00:19.892998
# Prepard filter set and sorted out geometry constraints: 0:00:00
# 1059286 records available
# ['taxonKey = 9606290', 'hasCoordinate = True', 'country = US', 'year >= 2001', 'year <= 2021', 'month >= 1', 'month <= 12', 'decimalLatitude >= 18', 'decimalLatitude <= 50', 'decimalLongitude >= -150', 'decimalLongitude <= -67']
# Your download key is  0264387-200613084148143
# Downloading Darwin Core Archive zip file for this species .....
# Download file size: 251970972 bytes
# On disk at T:/Occurrence_Records//0264387-200613084148143.zip
# Download complete: 0:10:28.384683
# Stored GBIF Download DOI etc.: 0:00:00.004979
# Summarized fields returned: 0:00:06.614869
# Prepared GBIF records for processing: 0:00:27.408522

# %%
# Filter out records with undesirable values, locations, and/or duplication.
#import importlib
#importlib.reload(functions)
for x in filter_set.keys():
    if filter_set[x] == "":
        filter_set[x] = None

# %%
functions.process_records(ebird_data=ebird_data, gbif_data=gbif_data, filter_set=filter_set, 
                        taxon_info=taxon_info, working_directory=working_directory, 
                        query_name=query_name)
# Out:
# Prepared data frames for processing: 0:00:15.015465
# Summarized values acquired: 0:00:03.705047
# Number of georeferenced records: 560190
# Number of record without georeference: 230020
# Applying default coordinate uncertainties
# Prepared and georeferenced records:0:00:04.953269
# Performed filtering: 0:00:08.694795
# DUPLICATES ON LATITUDE, LONGITUDE, DATE-TIME INCLUDED
# Saved summary of filtering results: 0:00:02.573775

# %%
output_db_conn= sqlite3.connect(output_database)
cursor = output_db_conn.cursor()
record_count = cursor.execute("SELECT COUNT(record_id) FROM occurrence_records;").fetchone()
print(str(record_count[0]) + " records were saved in the output database")
# Out:
# 787963 records were saved in the output database

# %% [markdown]
# ## Results of the Filtering

# %% [markdown]
# #### Attributes Returned for GBIF Records
# This count was made before filters were applied

# %%
if ask_GBIF == True:
    fields_summary = pd.read_sql("SELECT * FROM gbif_fields_returned", output_db_conn)
    fields_summary.index.name = 'Field'
    pd.set_option('display.max_rows', 250)
    print(fields_summary.sort_values(by="attribute"))
if ask_GBIF == False:
    print("GBIF was not queried.")
# Out:
#                                  attribute  included(n)  populated(n)
# Field
# 0                                 abstract      1059284             0
# 182                      acceptedNameUsage      1059284             0
# 175                    acceptedNameUsageID      1059284       1059284
# 230                 acceptedScientificName      1059284       1059284
# 219                       acceptedTaxonKey      1059284       1059284
# 1                             accessRights      1059284           164
# 2                            accrualMethod      1059284             0
# 3                       accrualPeriodicity      1059284             0
# 4                            accrualPolicy      1059284             0
# 5                              alternative      1059284             0
# 89                   associatedOccurrences      1059284             0
# 90                     associatedOrganisms      1059284             0
# 81                    associatedReferences      1059284             0
# 82                     associatedSequences      1059284             0
# 83                          associatedTaxa      1059284            41
# 6                                 audience      1059284             0
# 7                                available      1059284             0
# 62                           basisOfRecord      1059284       1059284
# 164                                    bed      1059284             0
# 76                                behavior      1059284           436
# 8                    bibliographicCitation      1059284           334
# 67                           catalogNumber      1059284       1059264
# 191                                  class      1059284       1059284
# 222                               classKey      1059284       1059284
# 59                          collectionCode      1059284       1059263
# 56                            collectionID      1059284           101
# 9                               conformsTo      1059284             0
# 115                              continent      1059284           415
# 10                             contributor      1059284             0
# 134                    coordinatePrecision      1059284             0
# 133          coordinateUncertaintyInMeters      1059284         20005
# 119                            countryCode      1059284       1059284
# 121                                 county      1059284       1034177
# 11                                coverage      1059284             0
# 12                                 created      1059284             0
# 13                                 creator      1059284             0
# 64                     dataGeneralizations      1059284            38
# 57                               datasetID      1059284            20
# 205                             datasetKey      1059284       1059284
# 60                             datasetName      1059284       1059284
# 14                                    date      1059284             0
# 15                            dateAccepted      1059284             0
# 16                         dateCopyrighted      1059284             0
# 169                         dateIdentified      1059284         24211
# 17                           dateSubmitted      1059284             0
# 103                                    day      1059284       1059279
# 131                        decimalLatitude      1059284       1059284
# 132                       decimalLongitude      1059284       1059284
# 210                                  depth      1059284             7
# 211                          depthAccuracy      1059284             7
# 18                             description      1059284             0
# 80                             disposition      1059284            14
# 212                   distanceAboveSurface      1059284             0
# 213           distanceAboveSurfaceAccuracy      1059284             0
# 65                       dynamicProperties      1059284            93
# 156               earliestAgeOrLowestStage      1059284             0
# 148            earliestEonOrLowestEonothem      1059284             0
# 154            earliestEpochOrLowestSeries      1059284             6
# 150             earliestEraOrLowestErathem      1059284             6
# 152           earliestPeriodOrLowestSystem      1059284             6
# 19                          educationLevel      1059284             0
# 208                              elevation      1059284            52
# 209                      elevationAccuracy      1059284            51
# 100                           endDayOfYear      1059284           434
# 77                      establishmentMeans      1059284           117
# 97                               eventDate      1059284       1059284
# 94                                 eventID      1059284             0
# 111                           eventRemarks      1059284            13
# 98                               eventTime      1059284         22982
# 20                                  extent      1059284             0
# 193                                 family      1059284       1059284
# 224                              familyKey      1059284       1059284
# 110                             fieldNotes      1059284            87
# 96                             fieldNumber      1059284           311
# 139                           footprintSRS      1059284             0
# 140                    footprintSpatialFit      1059284             0
# 138                           footprintWKT      1059284           291
# 21                                  format      1059284             0
# 162                              formation      1059284             0
# 229                            genericName      1059284       1059283
# 194                                  genus      1059284       1059284
# 225                               genusKey      1059284       1059284
# 249                          geodeticDatum      1059284       1059284
# 147                    geologicalContextID      1059284             0
# 143                   georeferenceProtocol      1059284           117
# 146                    georeferenceRemarks      1059284           307
# 144                    georeferenceSources      1059284            76
# 145         georeferenceVerificationStatus      1059284           168
# 141                        georeferencedBy      1059284            53
# 142                      georeferencedDate      1059284            53
# 161                                  group      1059284             0
# 105                                habitat      1059284             4
# 216                          hasCoordinate      1059284       1059284
# 22                               hasFormat      1059284             0
# 217                    hasGeospatialIssues      1059284       1059284
# 23                                 hasPart      1059284             0
# 24                              hasVersion      1059284             0
# 188                   higherClassification      1059284           396
# 114                        higherGeography      1059284           200
# 113                      higherGeographyID      1059284             7
# 159            highestBiostratigraphicZone      1059284             0
# 165                       identificationID      1059284         24176
# 166                identificationQualifier      1059284            31
# 170               identificationReferences      1059284             0
# 172                  identificationRemarks      1059284           223
# 171       identificationVerificationStatus      1059284            30
# 168                           identifiedBy      1059284         24231
# 239                         identifiedByID      1059284           472
# 25                              identifier      1059284       1059232
# 70                         individualCount      1059284        954599
# 63                     informationWithheld      1059284          1218
# 197                   infraspecificEpithet      1059284          1114
# 58                         institutionCode      1059284       1059001
# 55                           institutionID      1059284           181
# 26                     instructionalMethod      1059284             0
# 27                              isFormatOf      1059284             0
# 28                                isPartOf      1059284             0
# 29                          isReferencedBy      1059284             0
# 30                            isReplacedBy      1059284             0
# 31                            isRequiredBy      1059284             0
# 32                             isVersionOf      1059284             0
# 118                                 island      1059284             0
# 117                            islandGroup      1059284             0
# 214                                  issue      1059284         42285
# 33                                  issued      1059284             0
# 248                    iucnRedListCategory      1059284       1058170
# 189                                kingdom      1059284       1059284
# 220                             kingdomKey      1059284       1059284
# 34                                language      1059284           189
# 235                            lastCrawled      1059284       1059284
# 207                        lastInterpreted      1059284       1059284
# 234                             lastParsed      1059284       1059284
# 157                latestAgeOrHighestStage      1059284             0
# 149             latestEonOrHighestEonothem      1059284             0
# 155             latestEpochOrHighestSeries      1059284             0
# 151              latestEraOrHighestErathem      1059284             0
# 153            latestPeriodOrHighestSystem      1059284             0
# 240                              level0Gid      1059284       1057064
# 241                             level0Name      1059284       1057064
# 242                              level1Gid      1059284       1057064
# 243                             level1Name      1059284       1057064
# 244                              level2Gid      1059284       1057064
# 245                             level2Name      1059284       1057064
# 246                              level3Gid      1059284             7
# 247                             level3Name      1059284             7
# 35                                 license      1059284       1059284
# 74                               lifeStage      1059284           227
# 160                lithostratigraphicTerms      1059284             0
# 123                               locality      1059284       1034782
# 129                    locationAccordingTo      1059284            30
# 112                             locationID      1059284            22
# 130                        locationRemarks      1059284           311
# 158             lowestBiostratigraphicZone      1059284             6
# 93                        materialSampleID      1059284             0
# 128    maximumDistanceAboveSurfaceInMeters      1059284             0
# 215                              mediaType      1059284         23520
# 36                                mediator      1059284             0
# 37                                  medium      1059284             0
# 163                                 member      1059284             0
# 127    minimumDistanceAboveSurfaceInMeters      1059284             0
# 38                                modified      1059284         24649
# 102                                  month      1059284       1059284
# 122                           municipality      1059284             4
# 185                        nameAccordingTo      1059284             0
# 178                      nameAccordingToID      1059284             0
# 186                        namePublishedIn      1059284             0
# 179                      namePublishedInID      1059284             0
# 187                    namePublishedInYear      1059284             0
# 201                      nomenclaturalCode      1059284           258
# 203                    nomenclaturalStatus      1059284             0
# 66                            occurrenceID      1059284       1041972
# 85                       occurrenceRemarks      1059284          5176
# 78                        occurrenceStatus      1059284       1059284
# 192                                  order      1059284       1059284
# 223                               orderKey      1059284       1059284
# 86                              organismID      1059284            47
# 87                            organismName      1059284             0
# 71                        organismQuantity      1059284             7
# 72                    organismQuantityType      1059284             7
# 92                         organismRemarks      1059284             1
# 88                           organismScope      1059284             0
# 184                      originalNameUsage      1059284             0
# 177                    originalNameUsageID      1059284             0
# 84                     otherCatalogNumbers      1059284            45
# 61                    ownerInstitutionCode      1059284           321
# 95                           parentEventID      1059284             0
# 183                        parentNameUsage      1059284             0
# 176                      parentNameUsageID      1059284             0
# 190                                 phylum      1059284       1059284
# 221                              phylumKey      1059284       1059284
# 135                  pointRadiusSpatialFit      1059284             0
# 79                            preparations      1059284           139
# 91                 previousIdentifications      1059284            34
# 233                               protocol      1059284       1059284
# 39                              provenance      1059284             0
# 40                               publisher      1059284       1059284
# 206                      publishingCountry      1059284       1059284
# 68                            recordNumber      1059284            60
# 69                              recordedBy      1059284       1041821
# 238                           recordedByID      1059284           375
# 41                              references      1059284         25049
# 42                                relation      1059284             0
# 237               relativeOrganismQuantity      1059284             0
# 236                            repatriated      1059284       1059284
# 43                                replaces      1059284             0
# 75                   reproductiveCondition      1059284             3
# 44                                requires      1059284             0
# 45                                  rights      1059284         24383
# 46                            rightsHolder      1059284         24609
# 109                         sampleSizeUnit      1059284             0
# 108                        sampleSizeValue      1059284             0
# 107                         samplingEffort      1059284             0
# 106                       samplingProtocol      1059284           340
# 181                         scientificName      1059284       1059284
# 174                       scientificNameID      1059284             4
# 73                                     sex      1059284           112
# 47                                  source      1059284             0
# 48                                 spatial      1059284             0
# 228                                species      1059284       1059284
# 227                             speciesKey      1059284       1059284
# 196                        specificEpithet      1059284       1059283
# 99                          startDayOfYear      1059284           429
# 120                          stateProvince      1059284       1058946
# 195                               subgenus      1059284             0
# 226                            subgenusKey      1059284             0
# 49                                 subject      1059284             0
# 50                         tableOfContents      1059284             0
# 180                         taxonConceptID      1059284            20
# 173                                taxonID      1059284         24317
# 218                               taxonKey      1059284       1059284
# 198                              taxonRank      1059284       1059284
# 204                           taxonRemarks      1059284             4
# 202                        taxonomicStatus      1059284       1059284
# 51                                temporal      1059284             0
# 52                                   title      1059284             0
# 53                                    type      1059284           483
# 167                             typeStatus      1059284             0
# 232                           typifiedName      1059284             0
# 54                                   valid      1059284             0
# 136               verbatimCoordinateSystem      1059284            70
# 126                          verbatimDepth      1059284             0
# 125                      verbatimElevation      1059284            98
# 104                      verbatimEventDate      1059284         24567
# 124                       verbatimLocality      1059284         24696
# 137                            verbatimSRS      1059284             0
# 231                 verbatimScientificName      1059284       1059284
# 199                      verbatimTaxonRank      1059284             0
# 200                         vernacularName      1059284       1017512
# 116                              waterBody      1059284             0
# 101                                   year      1059284       1059284

# %% [markdown]
# #### Attributes Returned for eBird Records
# This count was made before filters were applied

# %%
if ask_eBird == True:
    fields_summary = pd.read_sql("SELECT * FROM ebird_fields_returned", output_db_conn)
    fields_summary.index.name = 'Field'
    pd.set_option('display.max_rows', 250)
    print(fields_summary)
if ask_eBird == False:
    print("No eBird Basic Dataset was queried.")
# Out:
#                            attribute  included(n)  populated(n)
# Field
# 0           global_unique_identifier       747794        747794
# 1                       checklist_id       747794        747794
# 2                       project_code       747794        747794
# 3                   last_edited_date       747794        747794
# 4                        common_name       747794        747794
# 5                  observation_count       747794        747794
# 6                           locality       747794        747794
# 7                           latitude       747794        747794
# 8                          longitude       747794        747794
# 9                   observation_date       747794        747794
# 10                       observer_id       747794        747794
# 11                effort_distance_km       747794        540185
# 12                     protocol_type       747794        747794
# 13                    effort_area_ha       747794          3005
# 14                     trip_comments       747794        166302
# 15                  species_comments       747794         79085
# 16                 effort_distance_m       747794        540185
# 17     coordinateUncertaintyInMeters       747794        540185
# 18                          geometry       747794        747794

# %% [markdown]
# #### Sources

# %%
sources = pd.read_sql(sql="SELECT * FROM sources;", con=output_db_conn)
print(sources[['institutionID', 'collectionCode', 'datasetName', 'acquired', 'removed', 'retained']])
# Out:
#                            institutionID collectionCode                                                               datasetName  acquired  removed  retained
# 0                                    clo          EBIRD                                                                       EBD    747794      354    747440
# 1   e3aa237e-53c8-4c46-93ef-77a18bb9c80e   Observations                              Biodiversity4all Research-Grade Observations         2        0         2
# 2                                    nan    Bird sounds                            Xeno-canto - Bird sounds from around the world        79        0        79
# 3                                    nan           BoBO            BoBO - Botanic Garden and Botanical Museum Berlin Observations         2        0         2
# 4                                    nan           GBBC                                                 Great Backyard Bird Count     17009        0     17009
# 5                                    nan   Observations                        Observation.org, Nature data from around the World       183        0       183
# 6                                    nan   Observations                                   iNaturalist Research-grade Observations     24317     1758     22559
# 7                                    nan             PC  U.S.D.A. Forest Service, Redwood Sciences Laboratory - Lamna Point Count        30        0        30
# 8                                    nan        PRBO-PC                               Point Reyes Bird Observatory - Point Counts       220        0       220
# 9                                    nan     Recordings                   Borror Lab of Bioacoustics (BLB), Ohio State University         4        0         4
# 10                                   nan             UF                             University of Florida Vertebrate Paleontology         6        0         6
# 11                                   nan          VBBA2                     The Second Breeding Bird Atlas of Vermont (2003-2007)       291        0       291
# 12                                   nan            nan                                               Earth Guardians Weekly Feed        19        0        19
# 13                                   nan            nan                                                                Gaia Guide         1        0         1
# 14                                   nan    naturgucker                                                               naturgucker        50        0        50
# 15                                   nan     user: 4815                                     Anymals+plants - Citizen Science Data         1        0         1
# 16                                   nan     user: 4925                                     Anymals+plants - Citizen Science Data         1        0         1
# 17         urn:lsid:biocol.org:col:34939             ML                               Macaulay Library Audio and Video Collection        66        0        66

# %% [markdown]
# #### Bases

# %%
bases = pd.read_sql(sql="SELECT * FROM attribute_value_counts WHERE attribute = 'basisOfRecord';", con=output_db_conn)
print(bases[['value', 'acquired', 'removed', 'retained']])
# Out:
#                  value  acquired  removed  retained
# 0      FOSSIL_SPECIMEN         6        0         6
# 1    HUMAN_OBSERVATION    772745     2113    770632
# 2  MACHINE_OBSERVATION        66        0        66
# 3          OBSERVATION     17259        0     17259

# %% [markdown]
# #### Protocols

# %%
protocols = pd.read_sql(sql="SELECT * FROM attribute_value_counts WHERE attribute = 'samplingProtocol';", con=output_db_conn)
if protocols.empty == True:
    print("No protocols were documented.")
if protocols.empty == False:
    print(protocols[['value', 'acquired', 'removed', 'retained']])
# Out:
#                                             value  acquired  removed  retained
# 0                                            Area       716        0       716
# 1                                        Atlasing       222        0       222
# 2                                   Block-busting        28        0        28
# 3                                      Casual Obs        39        0        39
# 4                     Great Texas Birding Classic         2        0         2
# 5             Greater Gulf Refuge Waterbird Count         3        0         3
# 6                                      Historical      1512        7      1505
# 7                                      Incidental      1530        0      1530
# 8            International Shorebird Survey (ISS)       139        0       139
# 9                                  My Yard Counts        23        0        23
# 10                                    Point Count         2        0         2
# 11                                         Random       398        0       398
# 12         Rusty Blackbird Spring Migration Blitz       250        0       250
# 13                        Standardized Yard Count         2        0         2
# 14                                     Stationary    208036        9    208027
# 15                                      Traveling    532573      335    532238
# 16                  Traveling - Property Specific      2588        0      2588
# 17                                Waterbird Count         1        0         1
# 18  Yellow-billed Magpie Survey - Traveling Count        18        0        18
# 19                                            nan     42076     1863     40213
# 20                                 none specified         4        0         4
# 21                                           seen        14        0        14
# 22                                 seen and heard         1        0         1

# %% [markdown]
# #### Issues

# %%
issues = pd.read_sql(sql="SELECT * FROM attribute_value_counts WHERE attribute = 'issues';", con=output_db_conn)
if issues.empty == True:
    print("No issues were documented.")
if issues.empty == False:
    print(issues[['value', 'acquired', 'removed', 'retained']])
# Out:
#                                                                          value  acquired  removed  retained
# 0                                                           COORDINATE_ROUNDED        98       36        62
# 1                          COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDINATES         1        0         1
# 2   COORDINATE_ROUNDED;COUNTRY_DERIVED_FROM_COORDINATES;GEODETIC_DATUM_ASSU...         2        1         1
# 3                                     COORDINATE_ROUNDED;FOOTPRINT_WKT_INVALID       291        0       291
# 4                              COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84     22896     1669     21227
# 5       COORDINATE_ROUNDED;GEODETIC_DATUM_ASSUMED_WGS84;TAXON_MATCH_HIGHERRANK        26        4        22
# 6                                             COUNTRY_DERIVED_FROM_COORDINATES         2        0         2
# 7                                                 GEODETIC_DATUM_ASSUMED_WGS84     18647       66     18581
# 8                    GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_PRECISION_INVALID        30        0        30
# 9                          GEODETIC_DATUM_ASSUMED_WGS84;TAXON_MATCH_HIGHERRANK         7        0         7
# 10                            OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT        53       25        28
# 11         OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT;COORDINATE_ROUNDED       163        4       159
# 12  OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT;GEODETIC_DATUM_ASSUMED...        13        9         4
# 13      OCCURRENCE_STATUS_INFERRED_FROM_INDIVIDUAL_COUNT;RECORDED_DATE_INVALID         2        0         2
# 14                                                                         nan    747925      379    747546

# %% [markdown]
# #### Establishment Means

# %%
establishment = pd.read_sql(sql="SELECT * FROM attribute_value_counts WHERE attribute = 'establishmentMeans';", con=output_db_conn)
if establishment.empty == True:
    print("No establishment means were reported.")
if establishment.empty == False:
    print(establishment[['value', 'acquired', 'removed', 'retained']])
# Out:
#     value  acquired  removed  retained
# 0  NATIVE       117       51        66
# 1     nan    790093     2196    787897

# %% [markdown]
# #### Identification Qualifiers

# %%
qualifications = pd.read_sql(sql="SELECT * FROM attribute_value_counts WHERE attribute = 'identificationQualifers';", con=output_db_conn)
if qualifications.empty == True:
    print("No identification qualifiers were reported.")
if qualifications.empty == False:
    print(establishment[['value', 'acquired', 'removed', 'retained']])
# Out:
# No identification qualifiers were reported.

# %% [markdown]
# ## Descriptions of Retained Records

# %% [markdown]
# #### Locations

# %%
# Get the record coordinates as a data frame
record_coordinates = (pd.read_sql("""SELECT decimalLatitude, decimalLongitude, radius_meters
                                     FROM occurrence_records""",
                                  con=output_db_conn)
                      .astype({'decimalLongitude': 'float', 'decimalLatitude': 'float',
                               'radius_meters': 'float'}))

# Make the data frame spatial
gdf = gpd.GeoDataFrame(record_coordinates, geometry=gpd.points_from_xy(record_coordinates['decimalLongitude'],
                                                   record_coordinates['decimalLatitude']))

# Set the coordinate reference system
gdf.crs={'init' :'epsg:4326'}

# Create world map <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
base = world.plot(figsize=(12,12), color = 'darkkhaki')
gdf.plot(ax=base, marker='o', color='k', markersize=5)
plt.show()

# Create USA map <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
if filter_set["country"] == "US":
    usa_bbox = np.array([-124.725839,   24.498131,  -66.949895,   49.384358])
    fig, ax = plt.subplots(figsize=(12,12))
    ax.set_xlim(([usa_bbox[0],  usa_bbox[2]]))
    ax.set_ylim(([usa_bbox[1],  usa_bbox[3]]))
    world.plot(ax=ax, color='darkkhaki')
    gdf.plot(ax=ax, marker='o', color='k', markersize=5)
    plt.show()

# Create coordinate extent map <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
os.chdir(config.codeDir)
states = gpd.read_file(os.getcwd() + '/data/us_states.shp')

# Reproject states and record coordinates to facilitate buffering
states = states.to_crs(epsg=5070)
footprints = gdf.to_crs(epsg=5070)

# Buffer points for record footprints
footprints['footprint']=footprints.apply(lambda x: x.geometry.buffer(x.radius_meters), axis=1)
footprints.set_geometry(col='footprint', inplace=True, drop=True)

# Map the buffered points/footprints
fig, ax = plt.subplots(figsize=(12,12))
coordinate_bbox = footprints.geometry.total_bounds
ax.set_xlim(([coordinate_bbox[0],  coordinate_bbox[2]]))
ax.set_ylim(([coordinate_bbox[1],  coordinate_bbox[3]]))
states.plot(ax=ax, color = 'darkkhaki')
footprints.boundary.plot(ax=ax, color='k')
plt.show()

# Cleanup
del footprints, gdf

# %% [markdown]
# #### Years Represented

# %%
occ_years = [int(x[0]) for x in cursor.execute("SELECT strftime('%Y', eventDate) FROM occurrence_records").fetchall()]
years = filter_set['years_range']
years = years.split(',')
yearsrng = list(range(int(years[0]), int(years[1]), 1))
binsnum = int(years[1]) - int(years[0])
plt.hist(occ_years, bins=binsnum)
plt.ylabel("number of records")
plt.xlabel("year")
plt.xticks(yearsrng, rotation=90)
plt.title("Occurrences per Year")
# Out:
# Text(0.5, 1.0, 'Occurrences per Year')

# %% [markdown]
# #### Months Represented

# %%
occ_months = [int(x[0]) for x in cursor.execute("SELECT strftime('%m', eventDate) FROM occurrence_records").fetchall()]
plt.hist(occ_months, bins=range(1, 14), color="g")
plt.ylabel("number of records")
plt.xlabel("month")
plt.xticks(range(1, 13))
plt.title("Occurrences per Month")
# Out:
# Text(0.5, 1.0, 'Occurrences per Month')

# %% [markdown]
# #### Distribution of Coordinate Uncertainty Values for Retained Records

# %%
occ_cert = [float(x[0]) for x in cursor.execute("SELECT coordinateUncertaintyInMeters FROM occurrence_records").fetchall()]
maxi = max(occ_cert)
plt.figure(figsize=(16,4))
plt.hist(occ_cert, bins=50, color="r")
plt.xticks(range(0, int(maxi), int(maxi/50)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("meters")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
occ_cert = [float(x[0]) for x in cursor.execute("SELECT coordinateUncertaintyInMeters FROM occurrence_records").fetchall()]
plt.figure(figsize=(11,4))
plt.boxplot(occ_cert, vert=False)
plt.xlabel("meters")
plt.title("Coordinate Uncertainty")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainty')

# %%
rng_max = 2000
occ_cert2 = [x for x in occ_cert if x <= rng_max]
plt.figure(figsize=(12,4))
plt.hist(occ_cert2, bins=30, color="m", align='mid')
plt.xticks(range(0, rng_max + 100, int(rng_max/30.)), rotation=90)
plt.ylabel("number of records")
plt.xlabel("meters")
plt.title("Coordinate Uncertainties Below 2km")
# Out:
# Text(0.5, 1.0, 'Coordinate Uncertainties Below 2km')

# %% [markdown]
# #### Remarks

# %%
print("General remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT general_remarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# General remarks:
# nan

# %%
print("Event remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT eventRemarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# Event remarks:
# More than 20 remarks, consult the occurrence database.

# %%
print("Occurrence remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT occurrenceRemarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# Occurrence remarks:
# More than 20 remarks, consult the occurrence database.

# %%
print("Location remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT locationRemarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# Location remarks:
# nan
# survey block type: priority
# survey block type: secondary
# survey block type: nonpriority

# %%
print("Identified remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT general_remarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# Identified remarks:
# nan

# %%
print("Georeference remarks:")
remarks = output_db_conn.execute("SELECT DISTINCT georeferenceRemarks FROM occurrence_records;").fetchall()
if len(remarks) <= 20:
    try:
        for rem in remarks:
            if rem[0][0:1] == ';':
                print(rem[0][2:])
            else:
                print(rem[0])
    except:
        pass
else:
    print("More than 20 remarks, consult the occurrence database.")
# Out:
# Georeference remarks:
# nan
# spatial footprint=1/6 block from USGS 1:24000 map used as survey area and point is centroid.
# CoordinateUncertaintyInMeters: 958
# Locality: BLB; coordinates given by recordist (Sam Fittton; GPS)
# Locality: BLB

# %% [markdown]
# ## Citations
# #### eBird

# %%
if ask_eBird == True:
    with open(config.EBD_file[:-22] + "recommended_citation.txt", "r") as reference:
        print(reference.readlines()[0])
else:
    print("No eBird Basic Dataset was queried")
# Out:
# eBird Basic Dataset. Version: EBD_relDec-2020. Cornell Lab of Ornithology, Ithaca, New York. Dec 2020.

# %% [markdown]
# #### GBIF

# %%
if ask_GBIF == True:
    if get_dwca == True:
        print("Citations-- ")
        print(cursor.execute("SELECT citations FROM GBIF_download_info").fetchall()[0][0])
    else:
        print("Set 'get_dwca' to True to acquire a list of citations")
if ask_GBIF == False:
    print("GBIF was not queried.")
# Out:
# Citations--
# When using this dataset please use the following citation and pay attention to the rights documented in rights.txt:
# Orrell T, Informatics Office (2021). NMNH Extant Specimen Records. Version 1.43. National Museum of Natural History, Smithsonian Institution. Occurrence dataset https://doi.org/10.15468/hnhrg3 accessed via GBIF.org on 2021-04-29.
# Unitt P (2019). SDNHM Birds Collection. San Diego Natural History Museum. Occurrence dataset https://doi.org/10.15468/dot7ae accessed via GBIF.org on 2021-04-29.
# Trombone T (2013). AMNH Bird Collection. American Museum of Natural History. Occurrence dataset https://doi.org/10.15468/xvzdcm accessed via GBIF.org on 2021-04-29.
# Labedz T (2021). University of Nebraska State Museum Birds Collection. University of Nebraska State Museum. Occurrence dataset https://doi.org/10.15468/peacbt accessed via GBIF.org on 2021-04-29.
# Baskauf S (2014). Bioimages. Vanderbilt University. Occurrence dataset https://doi.org/10.15468/jib4rt accessed via GBIF.org on 2021-04-29.
# Krohn A (2021). Kenneth S. Norris Center for Natural History, University of California, Santa Cruz (UCSC) Bird specimens (Arctos). Version 1.18. Kenneth S. Norris Center for Natural History. Occurrence dataset https://doi.org/10.15468/untrrh accessed via GBIF.org on 2021-04-29.
# Atlas of Living Australia (2019). Gaia Guide. Occurrence dataset https://doi.org/10.15468/i1bc3o accessed via GBIF.org on 2021-04-29.
# Fahy K (2016). SBMNH Vertebrate Zoology. Version 5.1. Santa Barbara Museum of Natural History. Occurrence dataset https://doi.org/10.15468/amfnkq accessed via GBIF.org on 2021-04-29.
# Prestridge H (2021). Biodiversity Research and Teaching Collections - TCWC Vertebrates. Version 9.4. Texas A&M University Biodiversity Research and Teaching Collections. Occurrence dataset https://doi.org/10.15468/szomia accessed via GBIF.org on 2021-04-29.
# Botanic Garden and Botanical Museum Berlin (2019). BoBO - Botanic Garden and Botanical Museum Berlin Observations. Occurrence dataset https://doi.org/10.15468/9ll2gz accessed via GBIF.org on 2021-04-29.
# Museum fÃ¼r Naturkunde Berlin. Anymals+plants - Citizen Science Data. Occurrence dataset https://doi.org/10.15468/ee6ps6 accessed via GBIF.org on 2021-04-29.
# Citizen Science Observation Dataset B, Tiago P (2020). Biodiversity4all Research-Grade Observations. BioDiversity4All. Occurrence dataset https://doi.org/10.15468/njmmp7 accessed via GBIF.org on 2021-04-29.
# Robbins M (2020). KUBI Ornithology Collection. Version 10.27. University of Kansas Biodiversity Institute. Occurrence dataset https://doi.org/10.15468/hlh5ud accessed via GBIF.org on 2021-04-29.
# Gall L (2021). Vertebrate Zoology Division - Ornithology, Yale Peabody Museum. Yale University Peabody Museum. Occurrence dataset https://doi.org/10.15468/h25uz7 accessed via GBIF.org on 2021-04-29.
# Nelson D, Johnson N (2018). Borror Lab of Bioacoustics (BLB), Ohio State University. Version 84.36. Museum of Biological Diversity, The Ohio State University. Occurrence dataset https://doi.org/10.15468/wyz5x9 accessed via GBIF.org on 2021-04-29.
# Woods, Ph.D. J L (2016). DMNH Birds. Version 8.1. Delaware Museum of Natural History. Occurrence dataset https://doi.org/10.15468/b63cw6 accessed via GBIF.org on 2021-04-29.
# Rohwer V (2018). CUMV Bird Collection. Version 28.17. Cornell University Museum of Vertebrates. Occurrence dataset https://doi.org/10.15468/fyugn7 accessed via GBIF.org on 2021-04-29.
# Hulbert R, FLMNH O (2021). University of Florida Vertebrate Paleontology. Version 1.74. Florida Museum of Natural History. Occurrence dataset https://doi.org/10.15468/nelacx accessed via GBIF.org on 2021-04-29.
# Faucett R (2021). UWBM Ornithology Collection. University of Washington Burke Museum. Occurrence dataset https://doi.org/10.15468/a2cmfl accessed via GBIF.org on 2021-04-29.
# Harvard University M, Morris P J (2021). Museum of Comparative Zoology, Harvard University. Version 162.257. Museum of Comparative Zoology, Harvard University. Occurrence dataset https://doi.org/10.15468/p5rupv accessed via GBIF.org on 2021-04-29.
# Flannery M, Fong J (2021). CAS Ornithology (ORN). Version 126.271. California Academy of Sciences. Occurrence dataset https://doi.org/10.15468/ozz2u5 accessed via GBIF.org on 2021-04-29.
# UMMZ Birds Data Group, LSA IT A (2021). University of Michigan Museum of Zoology, Division of Birds. Version 14.33. University of Michigan Museum of Zoology. Occurrence dataset https://doi.org/10.15468/lns1qm accessed via GBIF.org on 2021-04-29.
# Spellman G (2021). DMNS Bird Collection (Arctos). Version 34.48. Denver Museum of Nature & Science. Occurrence dataset https://doi.org/10.15468/t3bsxx accessed via GBIF.org on 2021-04-29.
# Grant S, Marks B (2020). Field Museum of Natural History (Zoology) Bird Collection. Version 14.19. Field Museum. Occurrence dataset https://doi.org/10.15468/exkxdx accessed via GBIF.org on 2021-04-29.
# Cicero C (2021). MVZ Bird Collection (Arctos). Version 43.48. Museum of Vertebrate Zoology. Occurrence dataset https://doi.org/10.15468/r1woj3 accessed via GBIF.org on 2021-04-29.
# Questagame (2021). Earth Guardians Weekly Feed. Occurrence dataset https://doi.org/10.15468/slqqt8 accessed via GBIF.org on 2021-04-29.
# Avian Knowledge Network. U.S.D.A. Forest Service, Redwood Sciences Laboratory - Lamna Point Count. Occurrence dataset https://doi.org/10.15468/yipupw accessed via GBIF.org on 2021-04-29.
# Feeney R (2019). LACM Vertebrate Collection. Version 18.7. Natural History Museum of Los Angeles County. Occurrence dataset https://doi.org/10.15468/77rmwd accessed via GBIF.org on 2021-04-29.
# naturgucker.de. naturgucker. Occurrence dataset https://doi.org/10.15468/uc1apo accessed via GBIF.org on 2021-04-29.
# Scholes III, Ph.D. E (2015). Macaulay Library Audio and Video Collection. Cornell Lab of Ornithology. Occurrence dataset https://doi.org/10.15468/ckcdpy accessed via GBIF.org on 2021-04-29.
# Vellinga W (2021). Xeno-canto - Bird sounds from around the world. Xeno-canto Foundation for Nature Sounds. Occurrence dataset https://doi.org/10.15468/qv0ksn accessed via GBIF.org on 2021-04-29.
# de Vries H, Lemmens M. Observation.org, Nature data from around the World. Observation.org. Occurrence dataset https://doi.org/10.15468/5nilie accessed via GBIF.org on 2021-04-29.
# Avian Knowledge Network. Point Reyes Bird Observatory - Point Counts. Occurrence dataset https://doi.org/10.15468/voayd4 accessed via GBIF.org on 2021-04-29.
# Renfrew R, McFarland K, Parren S (2020). The Second Breeding Bird Atlas of Vermont (2003-2007). Version 1.3. Vermont Center for Ecostudies. Occurrence dataset https://doi.org/10.15468/4y5cuq accessed via GBIF.org on 2021-04-29.
# Avian Knowledge Network. Great Backyard Bird Count. Occurrence dataset https://doi.org/10.15468/dml1pk accessed via GBIF.org on 2021-04-29.
# Ueda K (2021). iNaturalist Research-grade Observations. iNaturalist.org. Occurrence dataset https://doi.org/10.15468/ab3s5x accessed via GBIF.org on 2021-04-29.
# Levatich T, Ligocki S (2020). EOD - eBird Observation Dataset. Cornell Lab of Ornithology. Occurrence dataset https://doi.org/10.15468/aomfnb accessed via GBIF.org on 2021-04-29.

# %%
if ask_GBIF == True:
    if get_dwca == True:
        print("Rights-- ")
        print(output_db_conn.execute("SELECT rights FROM GBIF_download_info").fetchall()[0][0])
    else:
        print("Set 'get_dwca' to True to see the rights")
if ask_GBIF == False:
    print("GBIF was not queried.")
# Out:
# Rights--
#
# Dataset: NMNH Extant Specimen Records
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: SDNHM Birds Collection
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: AMNH Bird Collection
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: University of Nebraska State Museum Birds Collection
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: Bioimages
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: Kenneth S. Norris Center for Natural History, University of California, Santa Cruz (UCSC) Bird specimens (Arctos)
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: Gaia Guide
# Rights as supplied: http://creativecommons.org/licenses/by/4.0/legalcode
# Dataset: SBMNH Vertebrate Zoology
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: Biodiversity Research and Teaching Collections - TCWC Vertebrates
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: BoBO - Botanic Garden and Botanical Museum Berlin Observations
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: Anymals+plants - Citizen Science Data
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: Biodiversity4all Research-Grade Observations
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: KUBI Ornithology Collection
# Rights as supplied: http://creativecommons.org/licenses/by/4.0/legalcode
# Dataset: Vertebrate Zoology Division - Ornithology, Yale Peabody Museum
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: Borror Lab of Bioacoustics (BLB), Ohio State University
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: DMNH Birds
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: CUMV Bird Collection
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: University of Florida Vertebrate Paleontology
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: UWBM Ornithology Collection
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: Museum of Comparative Zoology, Harvard University
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: CAS Ornithology (ORN)
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: University of Michigan Museum of Zoology, Division of Birds
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: DMNS Bird Collection (Arctos)
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: Field Museum of Natural History (Zoology) Bird Collection
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: MVZ Bird Collection (Arctos)
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: Earth Guardians Weekly Feed
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: U.S.D.A. Forest Service, Redwood Sciences Laboratory - Lamna Point Count
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: LACM Vertebrate Collection
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: naturgucker
# Rights as supplied: http://creativecommons.org/licenses/by/4.0/legalcode
# Dataset: Macaulay Library Audio and Video Collection
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: Xeno-canto - Bird sounds from around the world
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: Observation.org, Nature data from around the World
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: Point Reyes Bird Observatory - Point Counts
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: The Second Breeding Bird Atlas of Vermont (2003-2007)
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: Great Backyard Bird Count
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode
# Dataset: iNaturalist Research-grade Observations
# Rights as supplied: http://creativecommons.org/licenses/by-nc/4.0/legalcode
# Dataset: EOD - eBird Observation Dataset
# Rights as supplied: http://creativecommons.org/publicdomain/zero/1.0/legalcode

# %%
if ask_GBIF == True:
    if get_dwca == True:
        print("DOI-- ")
        doi = output_db_conn.execute("SELECT doi FROM GBIF_download_info").fetchall()[0][0]
        print("https://doi.org/" + doi)
    else:
        print("Set 'get_dwca' to True to perform a search with a doi assigned")
if ask_GBIF == False:
    print("GBIF was not queried.")
# Out:
# DOI--
# https://doi.org/10.15468/dl.64n497

# %%
if ask_GBIF == True:
    if get_dwca == True:
        print("GBIF download key-- ")
        print(output_db_conn.execute("SELECT download_key FROM GBIF_download_info").fetchall()[0][0])
    else:
        print("Set 'get_dwca' to True to perform a search with a download key assigned")
if ask_GBIF == False:
    print("GBIF was not queried")
# Out:
# GBIF download key--
# 0264387-200613084148143

# %% [markdown]
# ## Runtime

# %%
output_db_conn.close()
del cursor
t2 = datetime.now()
print(t2 - t1)
# Out:
# 0:50:32.579041
